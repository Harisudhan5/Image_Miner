# %%
import cv2
import numpy as np
from PIL import Image
import pytesseract

# Load the image
image_path = '2.png'
image = cv2.imread(image_path)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Use Tesseract to extract word boxes and text
boxes_data = pytesseract.image_to_boxes(rgb_image)
extracted_text = pytesseract.image_to_string(rgb_image)

# Convert the image to grayscale for style analysis
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply edge detection
edges = cv2.Canny(gray_image, 50, 150)

# Find contours in the edge-detected image
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Analyze contours to infer style information for each letter
letter_styles = []

for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)

    # Use bounding box information to infer style (e.g., bold or italic)
    aspect_ratio = w / h
    if aspect_ratio > 1.5:
        style = "Bold"
    elif aspect_ratio < 0.5:
        style = "Italic"
    else:
        style = "Regular"

    # Append style for each letter in the contour
    for letter_x in range(x, x + w):
        letter_styles.append(style)

# Iterate through each word box and extract color, style, and position for each word
for box_data in boxes_data.splitlines():
    box = box_data.split()
    x, y, w, h = int(box[1]), int(box[2]), int(box[3]), int(box[4])
    word_image = rgb_image[y:h, x:w]
    average_word_color = np.mean(word_image, axis=(0, 1)).astype(int)
    word = box_data[0]

    # Print each letter, its color, style, and position
    print("Word:", word)
    print("  Position: x1={}, y1={}, x2={}, y2={}".format(x, y, w, h))
    
    # Extract style for each letter in the word
    for i, letter in enumerate(word):
        letter_style = letter_styles[x + i]  # Assuming x is the starting x-coordinate of the word
        print(f"    Letter: {letter}, Color: {tuple(average_word_color)}, Style: {letter_style}")

    print("\n")
# Out:
# Word: T
#   Position: x1=783, y1=935, x2=804, y2=963
#     Letter: T, Color: (137, 171, 175), Style: Regular
#
#
# Word: r
#   Position: x1=808, y1=935, x2=821, y2=956
#     Letter: r, Color: (118, 147, 152), Style: Regular
#
#
# Word: u
#   Position: x1=825, y1=935, x2=843, y2=956
#     Letter: u, Color: (127, 158, 164), Style: Regular
#
#
# Word: e
#   Position: x1=848, y1=935, x2=867, y2=956
#     Letter: e, Color: (112, 140, 146), Style: Regular
#
#
# Word: P
#   Position: x1=882, y1=935, x2=902, y2=963
#     Letter: P, Color: (108, 135, 142), Style: Regular
#
#
# Word: o
#   Position: x1=896, y1=935, x2=917, y2=965
#     Letter: o, Color: (106, 133, 140), Style: Regular
#
#
# Word: s
#   Position: x1=906, y1=935, x2=927, y2=956
#     Letter: s, Color: (119, 149, 158), Style: Regular
#
#
# Word: i
#   Position: x1=930, y1=935, x2=947, y2=956
#     Letter: i, Color: (129, 160, 171), Style: Regular
#
#
# Word: t
#   Position: x1=951, y1=935, x2=975, y2=965
#     Letter: t, Color: (108, 135, 145), Style: Regular
#
#
# Word: i
#   Position: x1=978, y1=935, x2=985, y2=965
#     Letter: i, Color: (175, 219, 235), Style: Italic
#
#
# Word: v
#   Position: x1=988, y1=935, x2=1009, y2=956
#     Letter: v, Color: (107, 134, 145), Style: Regular
#
#
# Word: e
#   Position: x1=1012, y1=935, x2=1031, y2=956
#     Letter: e, Color: (101, 127, 138), Style: Regular
#
#
# Word: s
#   Position: x1=1034, y1=935, x2=1051, y2=956
#     Letter: s, Color: (106, 133, 145), Style: Regular
#
#
# Word: (
#   Position: x1=1064, y1=931, x2=1074, y2=965
#     Letter: (, Color: (109, 136, 150), Style: Regular
#
#
# Word: T
#   Position: x1=1076, y1=935, x2=1098, y2=963
#     Letter: T, Color: (99, 123, 136), Style: Italic
#
#
# Word: P
#   Position: x1=1102, y1=935, x2=1122, y2=963
#     Letter: P, Color: (125, 157, 174), Style: Regular
#
#
# Word: )
#   Position: x1=1126, y1=931, x2=1135, y2=965
#     Letter: ), Color: (113, 141, 158), Style: Regular
#
#
# Word: I
#   Position: x1=103, y1=880, x2=109, y2=908
#     Letter: I, Color: (114, 142, 123), Style: Regular
#
#
# Word: n
#   Position: x1=115, y1=880, x2=134, y2=902
#     Letter: n, Color: (134, 167, 146), Style: Regular
#
#
# Word: s
#   Position: x1=138, y1=880, x2=155, y2=902
#     Letter: s, Color: (113, 140, 123), Style: Regular
#
#
# Word: t
#   Position: x1=157, y1=880, x2=172, y2=906
#     Letter: t, Color: (139, 173, 152), Style: Regular
#
#
# Word: a
#   Position: x1=174, y1=880, x2=195, y2=902
#     Letter: a, Color: (121, 151, 134), Style: Regular
#
#
# Word: n
#   Position: x1=198, y1=880, x2=217, y2=902
#     Letter: n, Color: (126, 157, 140), Style: Regular
#
#
# Word: c
#   Position: x1=222, y1=880, x2=241, y2=902
#     Letter: c, Color: (138, 173, 154), Style: Regular
#
#
# Word: e
#   Position: x1=243, y1=880, x2=263, y2=902
#     Letter: e, Color: (130, 161, 145), Style: Regular
#
#
# Word: s
#   Position: x1=266, y1=880, x2=283, y2=902
#     Letter: s, Color: (165, 206, 186), Style: Regular
#
#
# Word: a
#   Position: x1=295, y1=880, x2=315, y2=902
#     Letter: a, Color: (122, 152, 138), Style: Regular
#
#
# Word: c
#   Position: x1=317, y1=880, x2=336, y2=902
#     Letter: c, Color: (143, 178, 163), Style: Regular
#
#
# Word: c
#   Position: x1=339, y1=880, x2=358, y2=902
#     Letter: c, Color: (140, 175, 161), Style: Regular
#
#
# Word: u
#   Position: x1=355, y1=871, x2=371, y2=910
#     Letter: u, Color: (143, 178, 165), Style: Regular
#
#
# Word: r
#   Position: x1=362, y1=880, x2=380, y2=901
#     Letter: r, Color: (132, 165, 152), Style: Regular
#
#
# Word: a
#   Position: x1=386, y1=880, x2=400, y2=901
#     Letter: a, Color: (124, 155, 144), Style: Regular
#
#
# Word: t
#   Position: x1=402, y1=880, x2=438, y2=906
#     Letter: t, Color: (113, 141, 132), Style: Regular
#
#
# Word: e
#   Position: x1=441, y1=880, x2=460, y2=902
#     Letter: e, Color: (123, 154, 145), Style: Regular
#
#
# Word: l
#   Position: x1=465, y1=880, x2=473, y2=910
#     Letter: l, Color: (102, 127, 120), Style: Regular
#
#
# Word: y
#   Position: x1=475, y1=871, x2=496, y2=901
#     Letter: y, Color: (147, 183, 174), Style: Regular
#
#
# Word: p
#   Position: x1=509, y1=871, x2=529, y2=902
#     Letter: p, Color: (137, 170, 164), Style: Regular
#
#
# Word: r
#   Position: x1=534, y1=880, x2=547, y2=901
#     Letter: r, Color: (126, 157, 151), Style: Regular
#
#
# Word: e
#   Position: x1=550, y1=880, x2=569, y2=902
#     Letter: e, Color: (111, 138, 134), Style: Regular
#
#
# Word: d
#   Position: x1=572, y1=880, x2=593, y2=910
#     Letter: d, Color: (91, 114, 111), Style: Regular
#
#
# Word: i
#   Position: x1=598, y1=880, x2=605, y2=910
#     Letter: i, Color: (77, 96, 94), Style: Regular
#
#
# Word: c
#   Position: x1=609, y1=880, x2=628, y2=902
#     Letter: c, Color: (131, 163, 160), Style: Regular
#
#
# Word: t
#   Position: x1=630, y1=880, x2=645, y2=906
#     Letter: t, Color: (104, 130, 128), Style: Regular
#
#
# Word: e
#   Position: x1=647, y1=880, x2=667, y2=902
#     Letter: e, Color: (109, 137, 136), Style: Regular
#
#
# Word: d
#   Position: x1=670, y1=880, x2=691, y2=910
#     Letter: d, Color: (91, 113, 113), Style: Italic
#
#
# Word: a
#   Position: x1=705, y1=880, x2=725, y2=902
#     Letter: a, Color: (116, 144, 145), Style: Regular
#
#
# Word: s
#   Position: x1=726, y1=880, x2=743, y2=902
#     Letter: s, Color: (112, 140, 142), Style: Regular
#
#
# Word: p
#   Position: x1=757, y1=871, x2=777, y2=902
#     Letter: p, Color: (132, 165, 168), Style: Regular
#
#
# Word: o
#   Position: x1=781, y1=880, x2=802, y2=902
#     Letter: o, Color: (114, 142, 146), Style: Regular
#
#
# Word: s
#   Position: x1=805, y1=880, x2=822, y2=902
#     Letter: s, Color: (101, 126, 130), Style: Regular
#
#
# Word: i
#   Position: x1=826, y1=880, x2=832, y2=910
#     Letter: i, Color: (93, 116, 120), Style: Regular
#
#
# Word: t
#   Position: x1=835, y1=880, x2=851, y2=906
#     Letter: t, Color: (100, 125, 130), Style: Regular
#
#
# Word: i
#   Position: x1=853, y1=880, x2=860, y2=910
#     Letter: i, Color: (117, 146, 153), Style: Regular
#
#
# Word: v
#   Position: x1=863, y1=880, x2=885, y2=901
#     Letter: v, Color: (110, 138, 144), Style: Regular
#
#
# Word: e
#   Position: x1=887, y1=880, x2=907, y2=902
#     Letter: e, Color: (109, 136, 143), Style: Regular
#
#
# Word: b
#   Position: x1=920, y1=880, x2=941, y2=910
#     Letter: b, Color: (122, 152, 162), Style: Regular
#
#
# Word: y
#   Position: x1=943, y1=871, x2=965, y2=901
#     Letter: y, Color: (135, 168, 180), Style: Regular
#
#
# Word: t
#   Position: x1=975, y1=880, x2=990, y2=906
#     Letter: t, Color: (150, 187, 201), Style: Italic
#
#
# Word: h
#   Position: x1=994, y1=880, x2=1013, y2=910
#     Letter: h, Color: (109, 136, 147), Style: Regular
#
#
# Word: e
#   Position: x1=1018, y1=880, x2=1037, y2=902
#     Letter: e, Color: (105, 131, 143), Style: Regular
#
#
# Word: m
#   Position: x1=1051, y1=880, x2=1082, y2=902
#     Letter: m, Color: (122, 152, 167), Style: Regular
#
#
# Word: o
#   Position: x1=1086, y1=880, x2=1107, y2=902
#     Letter: o, Color: (109, 136, 150), Style: Regular
#
#
# Word: d
#   Position: x1=1111, y1=880, x2=1131, y2=910
#     Letter: d, Color: (106, 133, 148), Style: Regular
#
#
# Word: e
#   Position: x1=1123, y1=880, x2=1143, y2=910
#     Letter: e, Color: (85, 106, 119), Style: Regular
#
#
# Word: l
#   Position: x1=1136, y1=880, x2=1156, y2=902
#     Letter: l, Color: (88, 110, 123), Style: Regular
#
#
# Word: .
#   Position: x1=1160, y1=880, x2=1178, y2=910
#     Letter: ., Color: (96, 120, 136), Style: Regular
#
#
# Word: T
#   Position: x1=1190, y1=880, x2=1212, y2=908
#     Letter: T, Color: (128, 160, 182), Style: Regular
#
#
# Word: h
#   Position: x1=1216, y1=880, x2=1235, y2=910
#     Letter: h, Color: (111, 139, 159), Style: Regular
#
#
# Word: e
#   Position: x1=1239, y1=880, x2=1259, y2=902
#     Letter: e, Color: (100, 125, 144), Style: Regular
#
#
# Word: s
#   Position: x1=1262, y1=880, x2=1279, y2=902
#     Letter: s, Color: (110, 138, 160), Style: Regular
#
#
# Word: e
#   Position: x1=1282, y1=880, x2=1301, y2=902
#     Letter: e, Color: (105, 132, 153), Style: Regular
#
#
# Word: a
#   Position: x1=1314, y1=880, x2=1334, y2=902
#     Letter: a, Color: (134, 167, 196), Style: Regular
#
#
# Word: r
#   Position: x1=1337, y1=880, x2=1351, y2=901
#     Letter: r, Color: (107, 134, 158), Style: Regular
#
#
# Word: e
#   Position: x1=1353, y1=880, x2=1372, y2=902
#     Letter: e, Color: (112, 140, 166), Style: Regular
#
#
# Word: c
#   Position: x1=1385, y1=880, x2=1404, y2=902
#     Letter: c, Color: (130, 162, 194), Style: Regular
#
#
# Word: a
#   Position: x1=1407, y1=880, x2=1427, y2=902
#     Letter: a, Color: (118, 147, 177), Style: Regular
#
#
# Word: s
#   Position: x1=1428, y1=880, x2=1446, y2=902
#     Letter: s, Color: (103, 129, 157), Style: Regular
#
#
# Word: e
#   Position: x1=1449, y1=880, x2=1468, y2=902
#     Letter: e, Color: (102, 128, 156), Style: Regular
#
#
# Word: s
#   Position: x1=1471, y1=880, x2=1488, y2=902
#     Letter: s, Color: (106, 133, 163), Style: Regular
#
#
# Word: w
#   Position: x1=1499, y1=880, x2=1528, y2=901
#     Letter: w, Color: (116, 145, 179), Style: Regular
#
#
# Word: h
#   Position: x1=1532, y1=880, x2=1551, y2=910
#     Letter: h, Color: (93, 116, 144), Style: Regular
#
#
# Word: e
#   Position: x1=1556, y1=879, x2=1575, y2=902
#     Letter: e, Color: (98, 122, 153), Style: Regular
#
#
# Word: r
#   Position: x1=1580, y1=880, x2=1593, y2=901
#     Letter: r, Color: (103, 129, 163), Style: Regular
#
#
# Word: e
#   Position: x1=1595, y1=879, x2=1615, y2=902
#     Letter: e, Color: (109, 136, 173), Style: Regular
#
#
# Word: t
#   Position: x1=1626, y1=879, x2=1642, y2=906
#     Letter: t, Color: (129, 161, 206), Style: Regular
#
#
# Word: h
#   Position: x1=1645, y1=880, x2=1664, y2=910
#     Letter: h, Color: (97, 121, 155), Style: Regular
#
#
# Word: e
#   Position: x1=1669, y1=879, x2=1688, y2=902
#     Letter: e, Color: (95, 119, 154), Style: Regular
#
#
# Word: m
#   Position: x1=1702, y1=880, x2=1733, y2=902
#     Letter: m, Color: (108, 135, 177), Style: Regular
#
#
# Word: o
#   Position: x1=1737, y1=879, x2=1758, y2=902
#     Letter: o, Color: (99, 124, 163), Style: Regular
#
#
# Word: d
#   Position: x1=1762, y1=879, x2=1783, y2=910
#     Letter: d, Color: (97, 122, 161), Style: Regular
#
#
# Word: e
#   Position: x1=1775, y1=879, x2=1795, y2=910
#     Letter: e, Color: (79, 99, 132), Style: Regular
#
#
# Word: l
#   Position: x1=1787, y1=879, x2=1820, y2=910
#     Letter: l, Color: (89, 111, 149), Style: Regular
#
#
# Word: c
#   Position: x1=105, y1=826, x2=124, y2=848
#     Letter: c, Color: (201, 250, 218), Style: Regular
#
#
# Word: o
#   Position: x1=127, y1=826, x2=148, y2=848
#     Letter: o, Color: (200, 250, 218), Style: Regular
#
#
# Word: r
#   Position: x1=141, y1=817, x2=157, y2=856
#     Letter: r, Color: (200, 249, 219), Style: Regular
#
#
# Word: r
#   Position: x1=152, y1=826, x2=182, y2=847
#     Letter: r, Color: (200, 248, 219), Style: Regular
#
#
# Word: e
#   Position: x1=184, y1=826, x2=204, y2=848
#     Letter: e, Color: (199, 247, 219), Style: Regular
#
#
# Word: c
#   Position: x1=197, y1=817, x2=217, y2=856
#     Letter: c, Color: (198, 247, 220), Style: Regular
#
#
# Word: t
#   Position: x1=207, y1=826, x2=227, y2=848
#     Letter: t, Color: (198, 247, 220), Style: Regular
#
#
# Word: l
#   Position: x1=228, y1=826, x2=255, y2=856
#     Letter: l, Color: (197, 246, 220), Style: Regular
#
#
# Word: y
#   Position: x1=256, y1=817, x2=278, y2=847
#     Letter: y, Color: (197, 245, 221), Style: Regular
#
#
# Word: i
#   Position: x1=290, y1=826, x2=297, y2=856
#     Letter: i, Color: (196, 244, 221), Style: Regular
#
#
# Word: d
#   Position: x1=301, y1=826, x2=322, y2=856
#     Letter: d, Color: (195, 243, 222), Style: Regular
#
#
# Word: e
#   Position: x1=326, y1=826, x2=346, y2=848
#     Letter: e, Color: (195, 242, 222), Style: Regular
#
#
# Word: n
#   Position: x1=350, y1=826, x2=370, y2=848
#     Letter: n, Color: (194, 241, 223), Style: Regular
#
#
# Word: t
#   Position: x1=373, y1=826, x2=388, y2=852
#     Letter: t, Color: (193, 241, 223), Style: Regular
#
#
# Word: i
#   Position: x1=391, y1=826, x2=397, y2=856
#     Letter: i, Color: (193, 240, 224), Style: Regular
#
#
# Word: f
#   Position: x1=401, y1=826, x2=416, y2=856
#     Letter: f, Color: (192, 240, 224), Style: Regular
#
#
# Word: i
#   Position: x1=418, y1=826, x2=424, y2=856
#     Letter: i, Color: (192, 239, 224), Style: Regular
#
#
# Word: e
#   Position: x1=428, y1=826, x2=448, y2=848
#     Letter: e, Color: (192, 239, 224), Style: Regular
#
#
# Word: s
#   Position: x1=451, y1=826, x2=468, y2=848
#     Letter: s, Color: (191, 238, 225), Style: Regular
#
#
# Word: t
#   Position: x1=479, y1=826, x2=517, y2=856
#     Letter: t, Color: (190, 236, 226), Style: Regular
#
#
# Word: h
#   Position: x1=509, y1=826, x2=525, y2=856
#     Letter: h, Color: (189, 236, 226), Style: Regular
#
#
# Word: e
#   Position: x1=521, y1=826, x2=541, y2=848
#     Letter: e, Color: (189, 235, 226), Style: Regular
#
#
# Word: p
#   Position: x1=555, y1=817, x2=575, y2=848
#     Letter: p, Color: (188, 234, 227), Style: Regular
#
#
# Word: r
#   Position: x1=580, y1=826, x2=593, y2=847
#     Letter: r, Color: (187, 233, 227), Style: Regular
#
#
# Word: e
#   Position: x1=595, y1=826, x2=615, y2=848
#     Letter: e, Color: (187, 232, 228), Style: Regular
#
#
# Word: s
#   Position: x1=618, y1=826, x2=635, y2=848
#     Letter: s, Color: (186, 232, 228), Style: Regular
#
#
# Word: e
#   Position: x1=638, y1=826, x2=657, y2=848
#     Letter: e, Color: (185, 231, 229), Style: Regular
#
#
# Word: n
#   Position: x1=662, y1=826, x2=681, y2=848
#     Letter: n, Color: (185, 230, 229), Style: Regular
#
#
# Word: c
#   Position: x1=686, y1=826, x2=705, y2=848
#     Letter: c, Color: (184, 229, 230), Style: Regular
#
#
# Word: e
#   Position: x1=707, y1=826, x2=727, y2=848
#     Letter: e, Color: (183, 228, 230), Style: Regular
#
#
# Word: o
#   Position: x1=739, y1=826, x2=760, y2=848
#     Letter: o, Color: (182, 227, 231), Style: Regular
#
#
# Word: f
#   Position: x1=763, y1=826, x2=778, y2=856
#     Letter: f, Color: (144, 140, 233), Style: Italic
#
#
# Word: t
#   Position: x1=787, y1=826, x2=825, y2=856
#     Letter: t, Color: (148, 148, 233), Style: Regular
#
#
# Word: h
#   Position: x1=817, y1=826, x2=837, y2=856
#     Letter: h, Color: (146, 145, 233), Style: Regular
#
#
# Word: e
#   Position: x1=830, y1=826, x2=849, y2=848
#     Letter: e, Color: (148, 150, 233), Style: Regular
#
#
# Word: p
#   Position: x1=863, y1=817, x2=907, y2=856
#     Letter: p, Color: (157, 173, 234), Style: Regular
#
#
# Word: h
#   Position: x1=901, y1=817, x2=921, y2=856
#     Letter: h, Color: (156, 170, 234), Style: Regular
#
#
# Word: e
#   Position: x1=912, y1=826, x2=931, y2=848
#     Letter: e, Color: (152, 162, 234), Style: Regular
#
#
# Word: n
#   Position: x1=936, y1=826, x2=955, y2=848
#     Letter: n, Color: (148, 152, 235), Style: Regular
#
#
# Word: o
#   Position: x1=960, y1=826, x2=980, y2=848
#     Letter: o, Color: (139, 131, 235), Style: Regular
#
#
# Word: m
#   Position: x1=985, y1=826, x2=1016, y2=848
#     Letter: m, Color: (148, 153, 235), Style: Regular
#
#
# Word: e
#   Position: x1=1021, y1=826, x2=1040, y2=848
#     Letter: e, Color: (143, 143, 236), Style: Regular
#
#
# Word: n
#   Position: x1=1033, y1=817, x2=1053, y2=856
#     Letter: n, Color: (151, 161, 236), Style: Regular
#
#
# Word: o
#   Position: x1=1045, y1=826, x2=1064, y2=848
#     Letter: o, Color: (146, 149, 236), Style: Regular
#
#
# Word: n
#   Position: x1=1068, y1=826, x2=1113, y2=848
#     Letter: n, Color: (144, 147, 237), Style: Regular
#
#
# Word: o
#   Position: x1=1127, y1=826, x2=1137, y2=848
#     Letter: o, Color: (120, 87, 236), Style: Regular
#
#
# Word: r
#   Position: x1=1127, y1=826, x2=1166, y2=848
#     Letter: r, Color: (146, 152, 237), Style: Regular
#
#
# Word: c
#   Position: x1=1177, y1=826, x2=1197, y2=848
#     Letter: c, Color: (169, 211, 240), Style: Regular
#
#
# Word: o
#   Position: x1=1199, y1=826, x2=1220, y2=848
#     Letter: o, Color: (169, 210, 240), Style: Regular
#
#
# Word: n
#   Position: x1=1213, y1=826, x2=1233, y2=856
#     Letter: n, Color: (168, 210, 240), Style: Regular
#
#
# Word: d
#   Position: x1=1225, y1=826, x2=1244, y2=848
#     Letter: d, Color: (168, 209, 241), Style: Regular
#
#
# Word: i
#   Position: x1=1248, y1=826, x2=1269, y2=856
#     Letter: i, Color: (167, 209, 241), Style: Regular
#
#
# Word: t
#   Position: x1=1274, y1=826, x2=1281, y2=856
#     Letter: t, Color: (167, 208, 241), Style: Regular
#
#
# Word: i
#   Position: x1=1284, y1=826, x2=1309, y2=856
#     Letter: i, Color: (166, 207, 242), Style: Regular
#
#
# Word: o
#   Position: x1=1313, y1=826, x2=1334, y2=848
#     Letter: o, Color: (165, 206, 242), Style: Regular
#
#
# Word: n
#   Position: x1=1338, y1=826, x2=1358, y2=848
#     Letter: n, Color: (164, 205, 243), Style: Regular
#
#
# Word: i
#   Position: x1=1372, y1=826, x2=1379, y2=856
#     Letter: i, Color: (164, 204, 243), Style: Regular
#
#
# Word: t
#   Position: x1=1381, y1=826, x2=1397, y2=852
#     Letter: t, Color: (163, 204, 244), Style: Regular
#
#
# Word: i
#   Position: x1=1409, y1=826, x2=1436, y2=856
#     Letter: i, Color: (162, 203, 244), Style: Regular
#
#
# Word: s
#   Position: x1=1429, y1=826, x2=1436, y2=856
#     Letter: s, Color: (162, 202, 245), Style: Regular
#
#
# Word: d
#   Position: x1=1448, y1=826, x2=1469, y2=856
#     Letter: d, Color: (161, 201, 245), Style: Regular
#
#
# Word: e
#   Position: x1=1474, y1=826, x2=1493, y2=848
#     Letter: e, Color: (160, 200, 246), Style: Regular
#
#
# Word: s
#   Position: x1=1496, y1=826, x2=1513, y2=848
#     Letter: s, Color: (160, 200, 246), Style: Regular
#
#
# Word: i
#   Position: x1=1517, y1=826, x2=1523, y2=856
#     Letter: i, Color: (159, 199, 246), Style: Regular
#
#
# Word: g
#   Position: x1=1526, y1=817, x2=1547, y2=850
#     Letter: g, Color: (159, 198, 247), Style: Regular
#
#
# Word: n
#   Position: x1=1551, y1=826, x2=1570, y2=848
#     Letter: n, Color: (158, 198, 247), Style: Regular
#
#
# Word: e
#   Position: x1=1574, y1=826, x2=1594, y2=848
#     Letter: e, Color: (157, 197, 248), Style: Regular
#
#
# Word: d
#   Position: x1=1597, y1=826, x2=1618, y2=856
#     Letter: d, Color: (157, 196, 248), Style: Regular
#
#
# Word: t
#   Position: x1=1631, y1=825, x2=1646, y2=852
#     Letter: t, Color: (156, 195, 249), Style: Regular
#
#
# Word: o
#   Position: x1=1648, y1=825, x2=1669, y2=848
#     Letter: o, Color: (155, 194, 249), Style: Regular
#
#
# Word: d
#   Position: x1=1682, y1=825, x2=1703, y2=856
#     Letter: d, Color: (154, 193, 250), Style: Regular
#
#
# Word: e
#   Position: x1=1701, y1=825, x2=1717, y2=856
#     Letter: e, Color: (154, 192, 250), Style: Regular
#
#
# Word: t
#   Position: x1=1707, y1=825, x2=1744, y2=852
#     Letter: t, Color: (153, 192, 251), Style: Regular
#
#
# Word: e
#   Position: x1=1747, y1=825, x2=1766, y2=848
#     Letter: e, Color: (152, 190, 251), Style: Regular
#
#
# Word: c
#   Position: x1=1757, y1=825, x2=1773, y2=856
#     Letter: c, Color: (152, 190, 251), Style: Regular
#
#
# Word: t
#   Position: x1=1770, y1=825, x2=1789, y2=848
#     Letter: t, Color: (152, 190, 252), Style: Regular
#
#
# Word: .
#   Position: x1=1790, y1=825, x2=1815, y2=852
#     Letter: ., Color: (151, 189, 252), Style: Regular
#
#
# Word: T
#   Position: x1=772, y1=717, x2=793, y2=745
#     Letter: T, Color: (181, 226, 231), Style: Regular
#
#
# Word: r
#   Position: x1=797, y1=717, x2=810, y2=738
#     Letter: r, Color: (181, 225, 232), Style: Regular
#
#
# Word: u
#   Position: x1=814, y1=717, x2=832, y2=738
#     Letter: u, Color: (180, 225, 232), Style: Regular
#
#
# Word: e
#   Position: x1=837, y1=717, x2=856, y2=738
#     Letter: e, Color: (179, 224, 233), Style: Regular
#
#
# Word: N
#   Position: x1=871, y1=717, x2=894, y2=745
#     Letter: N, Color: (135, 168, 177), Style: Regular
#
#
# Word: e
#   Position: x1=900, y1=717, x2=919, y2=738
#     Letter: e, Color: (115, 144, 152), Style: Regular
#
#
# Word: g
#   Position: x1=912, y1=708, x2=933, y2=747
#     Letter: g, Color: (132, 164, 174), Style: Regular
#
#
# Word: a
#   Position: x1=922, y1=708, x2=942, y2=741
#     Letter: a, Color: (124, 154, 164), Style: Regular
#
#
# Word: t
#   Position: x1=945, y1=717, x2=965, y2=738
#     Letter: t, Color: (118, 147, 157), Style: Regular
#
#
# Word: i
#   Position: x1=966, y1=717, x2=990, y2=747
#     Letter: i, Color: (110, 138, 148), Style: Regular
#
#
# Word: v
#   Position: x1=994, y1=717, x2=1015, y2=738
#     Letter: v, Color: (118, 147, 159), Style: Regular
#
#
# Word: e
#   Position: x1=1006, y1=708, x2=1027, y2=747
#     Letter: e, Color: (117, 146, 159), Style: Regular
#
#
# Word: s
#   Position: x1=1018, y1=717, x2=1057, y2=738
#     Letter: s, Color: (155, 193, 211), Style: Regular
#
#
# Word: (
#   Position: x1=1070, y1=713, x2=1080, y2=747
#     Letter: (, Color: (173, 215, 237), Style: Regular
#
#
# Word: T
#   Position: x1=1082, y1=717, x2=1104, y2=745
#     Letter: T, Color: (172, 215, 238), Style: Italic
#
#
# Word: N
#   Position: x1=1108, y1=717, x2=1132, y2=745
#     Letter: N, Color: (171, 214, 238), Style: Regular
#
#
# Word: )
#   Position: x1=1137, y1=713, x2=1146, y2=747
#     Letter: ), Color: (171, 213, 239), Style: Regular
#
#
# Word: I
#   Position: x1=97, y1=662, x2=103, y2=690
#     Letter: I, Color: (202, 251, 218), Style: Regular
#
#
# Word: n
#   Position: x1=109, y1=662, x2=129, y2=684
#     Letter: n, Color: (201, 250, 218), Style: Regular
#
#
# Word: s
#   Position: x1=132, y1=662, x2=150, y2=684
#     Letter: s, Color: (114, 142, 124), Style: Regular
#
#
# Word: t
#   Position: x1=151, y1=662, x2=167, y2=688
#     Letter: t, Color: (135, 168, 148), Style: Regular
#
#
# Word: a
#   Position: x1=169, y1=662, x2=189, y2=684
#     Letter: a, Color: (118, 147, 130), Style: Regular
#
#
# Word: n
#   Position: x1=192, y1=662, x2=212, y2=684
#     Letter: n, Color: (108, 134, 119), Style: Regular
#
#
# Word: c
#   Position: x1=216, y1=662, x2=235, y2=684
#     Letter: c, Color: (121, 151, 135), Style: Regular
#
#
# Word: e
#   Position: x1=238, y1=662, x2=257, y2=684
#     Letter: e, Color: (142, 176, 158), Style: Regular
#
#
# Word: s
#   Position: x1=260, y1=662, x2=277, y2=684
#     Letter: s, Color: (125, 156, 141), Style: Regular
#
#
# Word: a
#   Position: x1=289, y1=662, x2=310, y2=684
#     Letter: a, Color: (122, 153, 139), Style: Regular
#
#
# Word: c
#   Position: x1=312, y1=662, x2=331, y2=684
#     Letter: c, Color: (138, 172, 158), Style: Regular
#
#
# Word: c
#   Position: x1=334, y1=662, x2=353, y2=684
#     Letter: c, Color: (120, 150, 138), Style: Regular
#
#
# Word: u
#   Position: x1=345, y1=653, x2=365, y2=692
#     Letter: u, Color: (133, 166, 153), Style: Regular
#
#
# Word: r
#   Position: x1=356, y1=662, x2=375, y2=683
#     Letter: r, Color: (119, 149, 138), Style: Regular
#
#
# Word: a
#   Position: x1=381, y1=662, x2=394, y2=683
#     Letter: a, Color: (131, 163, 152), Style: Regular
#
#
# Word: t
#   Position: x1=396, y1=662, x2=416, y2=684
#     Letter: t, Color: (137, 170, 159), Style: Regular
#
#
# Word: e
#   Position: x1=417, y1=662, x2=433, y2=688
#     Letter: e, Color: (111, 139, 130), Style: Regular
#
#
# Word: l
#   Position: x1=435, y1=662, x2=468, y2=692
#     Letter: l, Color: (118, 147, 139), Style: Regular
#
#
# Word: y
#   Position: x1=469, y1=653, x2=490, y2=683
#     Letter: y, Color: (147, 183, 174), Style: Regular
#
#
# Word: p
#   Position: x1=503, y1=653, x2=524, y2=684
#     Letter: p, Color: (131, 163, 156), Style: Regular
#
#
# Word: r
#   Position: x1=528, y1=662, x2=542, y2=683
#     Letter: r, Color: (126, 157, 151), Style: Regular
#
#
# Word: e
#   Position: x1=544, y1=662, x2=563, y2=684
#     Letter: e, Color: (104, 130, 125), Style: Regular
#
#
# Word: d
#   Position: x1=567, y1=662, x2=587, y2=692
#     Letter: d, Color: (109, 136, 133), Style: Regular
#
#
# Word: i
#   Position: x1=593, y1=662, x2=599, y2=692
#     Letter: i, Color: (165, 205, 201), Style: Regular
#
#
# Word: c
#   Position: x1=604, y1=662, x2=623, y2=684
#     Letter: c, Color: (122, 153, 150), Style: Regular
#
#
# Word: t
#   Position: x1=624, y1=662, x2=639, y2=688
#     Letter: t, Color: (111, 139, 137), Style: Regular
#
#
# Word: e
#   Position: x1=642, y1=662, x2=661, y2=684
#     Letter: e, Color: (126, 157, 155), Style: Regular
#
#
# Word: d
#   Position: x1=665, y1=662, x2=685, y2=692
#     Letter: d, Color: (139, 173, 173), Style: Regular
#
#
# Word: a
#   Position: x1=699, y1=662, x2=719, y2=684
#     Letter: a, Color: (116, 145, 146), Style: Regular
#
#
# Word: s
#   Position: x1=721, y1=662, x2=738, y2=684
#     Letter: s, Color: (111, 139, 140), Style: Regular
#
#
# Word: n
#   Position: x1=752, y1=662, x2=771, y2=684
#     Letter: n, Color: (141, 176, 180), Style: Regular
#
#
# Word: e
#   Position: x1=775, y1=662, x2=795, y2=684
#     Letter: e, Color: (110, 137, 140), Style: Regular
#
#
# Word: g
#   Position: x1=797, y1=653, x2=817, y2=686
#     Letter: g, Color: (136, 170, 175), Style: Regular
#
#
# Word: a
#   Position: x1=820, y1=662, x2=840, y2=684
#     Letter: a, Color: (117, 146, 151), Style: Regular
#
#
# Word: t
#   Position: x1=841, y1=662, x2=856, y2=688
#     Letter: t, Color: (113, 140, 146), Style: Regular
#
#
# Word: i
#   Position: x1=859, y1=662, x2=866, y2=692
#     Letter: i, Color: (100, 125, 130), Style: Regular
#
#
# Word: v
#   Position: x1=869, y1=662, x2=890, y2=683
#     Letter: v, Color: (106, 132, 138), Style: Regular
#
#
# Word: e
#   Position: x1=893, y1=662, x2=912, y2=684
#     Letter: e, Color: (121, 151, 159), Style: Regular
#
#
# Word: b
#   Position: x1=926, y1=662, x2=946, y2=692
#     Letter: b, Color: (140, 175, 186), Style: Regular
#
#
# Word: y
#   Position: x1=949, y1=653, x2=970, y2=683
#     Letter: y, Color: (130, 162, 174), Style: Regular
#
#
# Word: t
#   Position: x1=981, y1=662, x2=996, y2=688
#     Letter: t, Color: (159, 199, 215), Style: Regular
#
#
# Word: h
#   Position: x1=1000, y1=662, x2=1019, y2=692
#     Letter: h, Color: (85, 106, 115), Style: Regular
#
#
# Word: e
#   Position: x1=1023, y1=662, x2=1043, y2=684
#     Letter: e, Color: (113, 141, 154), Style: Regular
#
#
# Word: m
#   Position: x1=1056, y1=662, x2=1087, y2=684
#     Letter: m, Color: (135, 168, 185), Style: Regular
#
#
# Word: o
#   Position: x1=1092, y1=662, x2=1113, y2=684
#     Letter: o, Color: (100, 125, 139), Style: Regular
#
#
# Word: d
#   Position: x1=1105, y1=662, x2=1125, y2=692
#     Letter: d, Color: (116, 144, 161), Style: Regular
#
#
# Word: e
#   Position: x1=1117, y1=662, x2=1137, y2=692
#     Letter: e, Color: (104, 129, 145), Style: Regular
#
#
# Word: l
#   Position: x1=1142, y1=662, x2=1161, y2=684
#     Letter: l, Color: (105, 132, 148), Style: Regular
#
#
# Word: .
#   Position: x1=1166, y1=662, x2=1184, y2=692
#     Letter: ., Color: (108, 135, 153), Style: Regular
#
#
# Word: T
#   Position: x1=1196, y1=662, x2=1218, y2=690
#     Letter: T, Color: (105, 131, 150), Style: Regular
#
#
# Word: h
#   Position: x1=1221, y1=662, x2=1240, y2=692
#     Letter: h, Color: (102, 128, 147), Style: Regular
#
#
# Word: e
#   Position: x1=1245, y1=662, x2=1264, y2=684
#     Letter: e, Color: (114, 142, 164), Style: Regular
#
#
# Word: s
#   Position: x1=1267, y1=662, x2=1284, y2=684
#     Letter: s, Color: (100, 125, 145), Style: Regular
#
#
# Word: e
#   Position: x1=1287, y1=662, x2=1307, y2=684
#     Letter: e, Color: (105, 132, 154), Style: Regular
#
#
# Word: a
#   Position: x1=1319, y1=662, x2=1340, y2=684
#     Letter: a, Color: (133, 166, 195), Style: Regular
#
#
# Word: r
#   Position: x1=1343, y1=662, x2=1356, y2=683
#     Letter: r, Color: (101, 127, 150), Style: Regular
#
#
# Word: e
#   Position: x1=1358, y1=662, x2=1378, y2=684
#     Letter: e, Color: (91, 114, 136), Style: Regular
#
#
# Word: c
#   Position: x1=1391, y1=662, x2=1410, y2=684
#     Letter: c, Color: (91, 114, 136), Style: Regular
#
#
# Word: a
#   Position: x1=1412, y1=662, x2=1432, y2=684
#     Letter: a, Color: (102, 128, 154), Style: Regular
#
#
# Word: s
#   Position: x1=1434, y1=662, x2=1451, y2=684
#     Letter: s, Color: (160, 200, 243), Style: Regular
#
#
# Word: e
#   Position: x1=1454, y1=662, x2=1474, y2=684
#     Letter: e, Color: (109, 136, 166), Style: Regular
#
#
# Word: s
#   Position: x1=1476, y1=662, x2=1494, y2=684
#     Letter: s, Color: (111, 138, 169), Style: Regular
#
#
# Word: w
#   Position: x1=1505, y1=662, x2=1534, y2=683
#     Letter: w, Color: (98, 123, 152), Style: Regular
#
#
# Word: h
#   Position: x1=1538, y1=662, x2=1557, y2=692
#     Letter: h, Color: (104, 130, 162), Style: Regular
#
#
# Word: e
#   Position: x1=1549, y1=661, x2=1569, y2=692
#     Letter: e, Color: (97, 121, 151), Style: Regular
#
#
# Word: r
#   Position: x1=1561, y1=662, x2=1599, y2=684
#     Letter: r, Color: (92, 115, 144), Style: Regular
#
#
# Word: e
#   Position: x1=1601, y1=661, x2=1621, y2=684
#     Letter: e, Color: (112, 140, 177), Style: Regular
#
#
# Word: t
#   Position: x1=1632, y1=661, x2=1647, y2=688
#     Letter: t, Color: (151, 189, 241), Style: Regular
#
#
# Word: h
#   Position: x1=1651, y1=662, x2=1670, y2=692
#     Letter: h, Color: (79, 99, 127), Style: Regular
#
#
# Word: e
#   Position: x1=1674, y1=661, x2=1694, y2=684
#     Letter: e, Color: (118, 147, 190), Style: Regular
#
#
# Word: m
#   Position: x1=1708, y1=662, x2=1739, y2=684
#     Letter: m, Color: (119, 149, 194), Style: Regular
#
#
# Word: o
#   Position: x1=1743, y1=661, x2=1764, y2=684
#     Letter: o, Color: (107, 134, 176), Style: Regular
#
#
# Word: d
#   Position: x1=1768, y1=661, x2=1788, y2=692
#     Letter: d, Color: (94, 117, 155), Style: Regular
#
#
# Word: e
#   Position: x1=1781, y1=661, x2=1801, y2=692
#     Letter: e, Color: (129, 161, 214), Style: Regular
#
#
# Word: l
#   Position: x1=1793, y1=661, x2=1826, y2=692
#     Letter: l, Color: (151, 189, 252), Style: Regular
#
#
# Word: c
#   Position: x1=107, y1=608, x2=126, y2=630
#     Letter: c, Color: (197, 245, 214), Style: Regular
#
#
# Word: o
#   Position: x1=129, y1=608, x2=149, y2=630
#     Letter: o, Color: (131, 163, 143), Style: Regular
#
#
# Word: r
#   Position: x1=154, y1=608, x2=168, y2=629
#     Letter: r, Color: (137, 170, 150), Style: Regular
#
#
# Word: r
#   Position: x1=171, y1=608, x2=184, y2=629
#     Letter: r, Color: (136, 170, 150), Style: Regular
#
#
# Word: e
#   Position: x1=186, y1=608, x2=206, y2=630
#     Letter: e, Color: (135, 168, 149), Style: Regular
#
#
# Word: c
#   Position: x1=209, y1=608, x2=228, y2=630
#     Letter: c, Color: (121, 151, 135), Style: Regular
#
#
# Word: t
#   Position: x1=230, y1=608, x2=245, y2=634
#     Letter: t, Color: (137, 170, 153), Style: Regular
#
#
# Word: l
#   Position: x1=248, y1=608, x2=257, y2=638
#     Letter: l, Color: (118, 147, 133), Style: Regular
#
#
# Word: y
#   Position: x1=258, y1=599, x2=280, y2=629
#     Letter: y, Color: (151, 188, 170), Style: Regular
#
#
# Word: r
#   Position: x1=292, y1=608, x2=306, y2=629
#     Letter: r, Color: (117, 146, 133), Style: Regular
#
#
# Word: e
#   Position: x1=308, y1=608, x2=327, y2=630
#     Letter: e, Color: (146, 182, 167), Style: Regular
#
#
# Word: c
#   Position: x1=331, y1=608, x2=350, y2=630
#     Letter: c, Color: (111, 138, 127), Style: Regular
#
#
# Word: o
#   Position: x1=353, y1=608, x2=373, y2=630
#     Letter: o, Color: (134, 167, 155), Style: Regular
#
#
# Word: g
#   Position: x1=376, y1=599, x2=397, y2=632
#     Letter: g, Color: (135, 168, 156), Style: Regular
#
#
# Word: n
#   Position: x1=400, y1=608, x2=419, y2=630
#     Letter: n, Color: (132, 164, 154), Style: Regular
#
#
# Word: i
#   Position: x1=424, y1=608, x2=431, y2=638
#     Letter: i, Color: (162, 202, 189), Style: Regular
#
#
# Word: z
#   Position: x1=435, y1=608, x2=451, y2=629
#     Letter: z, Color: (103, 129, 121), Style: Regular
#
#
# Word: e
#   Position: x1=454, y1=608, x2=474, y2=630
#     Letter: e, Color: (133, 166, 157), Style: Regular
#
#
# Word: s
#   Position: x1=476, y1=608, x2=493, y2=630
#     Letter: s, Color: (117, 146, 139), Style: Regular
#
#
# Word: t
#   Position: x1=505, y1=608, x2=520, y2=634
#     Letter: t, Color: (124, 155, 149), Style: Regular
#
#
# Word: h
#   Position: x1=523, y1=608, x2=543, y2=638
#     Letter: h, Color: (159, 198, 190), Style: Regular
#
#
# Word: e
#   Position: x1=547, y1=608, x2=567, y2=630
#     Letter: e, Color: (129, 161, 156), Style: Regular
#
#
# Word: a
#   Position: x1=579, y1=608, x2=599, y2=630
#     Letter: a, Color: (109, 136, 133), Style: Regular
#
#
# Word: b
#   Position: x1=602, y1=608, x2=623, y2=638
#     Letter: b, Color: (95, 119, 117), Style: Regular
#
#
# Word: s
#   Position: x1=626, y1=608, x2=643, y2=630
#     Letter: s, Color: (120, 149, 147), Style: Regular
#
#
# Word: e
#   Position: x1=646, y1=608, x2=666, y2=630
#     Letter: e, Color: (134, 167, 165), Style: Regular
#
#
# Word: n
#   Position: x1=670, y1=608, x2=689, y2=630
#     Letter: n, Color: (127, 159, 158), Style: Italic
#
#
# Word: c
#   Position: x1=683, y1=608, x2=703, y2=638
#     Letter: c, Color: (116, 144, 144), Style: Regular
#
#
# Word: e
#   Position: x1=694, y1=608, x2=735, y2=630
#     Letter: e, Color: (129, 160, 161), Style: Regular
#
#
# Word: o
#   Position: x1=748, y1=608, x2=769, y2=630
#     Letter: o, Color: (115, 144, 146), Style: Regular
#
#
# Word: f
#   Position: x1=771, y1=608, x2=787, y2=638
#     Letter: f, Color: (168, 209, 214), Style: Regular
#
#
# Word: t
#   Position: x1=796, y1=608, x2=811, y2=634
#     Letter: t, Color: (116, 145, 149), Style: Regular
#
#
# Word: h
#   Position: x1=815, y1=608, x2=834, y2=638
#     Letter: h, Color: (107, 133, 138), Style: Regular
#
#
# Word: e
#   Position: x1=838, y1=608, x2=858, y2=630
#     Letter: e, Color: (117, 147, 153), Style: Regular
#
#
# Word: p
#   Position: x1=872, y1=599, x2=916, y2=638
#     Letter: p, Color: (128, 160, 168), Style: Regular
#
#
# Word: h
#   Position: x1=920, y1=608, x2=940, y2=630
#     Letter: h, Color: (109, 136, 145), Style: Regular
#
#
# Word: e
#   Position: x1=931, y1=599, x2=951, y2=638
#     Letter: e, Color: (157, 196, 209), Style: Regular
#
#
# Word: n
#   Position: x1=944, y1=608, x2=964, y2=630
#     Letter: n, Color: (116, 144, 154), Style: Regular
#
#
# Word: o
#   Position: x1=968, y1=608, x2=989, y2=630
#     Letter: o, Color: (120, 150, 162), Style: Regular
#
#
# Word: m
#   Position: x1=994, y1=608, x2=1025, y2=630
#     Letter: m, Color: (137, 170, 185), Style: Regular
#
#
# Word: e
#   Position: x1=1019, y1=599, x2=1039, y2=638
#     Letter: e, Color: (126, 157, 171), Style: Regular
#
#
# Word: n
#   Position: x1=1029, y1=608, x2=1072, y2=630
#     Letter: n, Color: (113, 141, 155), Style: Regular
#
#
# Word: o
#   Position: x1=1063, y1=599, x2=1083, y2=638
#     Letter: o, Color: (152, 189, 209), Style: Regular
#
#
# Word: n
#   Position: x1=1077, y1=608, x2=1122, y2=630
#     Letter: n, Color: (111, 139, 154), Style: Italic
#
#
# Word: o
#   Position: x1=1135, y1=608, x2=1156, y2=630
#     Letter: o, Color: (118, 147, 165), Style: Regular
#
#
# Word: r
#   Position: x1=1161, y1=608, x2=1174, y2=629
#     Letter: r, Color: (108, 135, 152), Style: Regular
#
#
# Word: c
#   Position: x1=1186, y1=608, x2=1205, y2=630
#     Letter: c, Color: (120, 150, 171), Style: Regular
#
#
# Word: o
#   Position: x1=1208, y1=608, x2=1228, y2=630
#     Letter: o, Color: (156, 195, 223), Style: Regular
#
#
# Word: n
#   Position: x1=1233, y1=608, x2=1252, y2=630
#     Letter: n, Color: (90, 112, 129), Style: Regular
#
#
# Word: d
#   Position: x1=1243, y1=608, x2=1263, y2=638
#     Letter: d, Color: (100, 125, 145), Style: Regular
#
#
# Word: i
#   Position: x1=1257, y1=608, x2=1277, y2=638
#     Letter: i, Color: (104, 130, 151), Style: Regular
#
#
# Word: t
#   Position: x1=1283, y1=608, x2=1289, y2=638
#     Letter: t, Color: (87, 109, 127), Style: Regular
#
#
# Word: i
#   Position: x1=1292, y1=608, x2=1317, y2=638
#     Letter: i, Color: (104, 130, 152), Style: Regular
#
#
# Word: o
#   Position: x1=1315, y1=608, x2=1331, y2=638
#     Letter: o, Color: (85, 106, 124), Style: Regular
#
#
# Word: n
#   Position: x1=1321, y1=608, x2=1366, y2=630
#     Letter: n, Color: (120, 150, 177), Style: Regular
#
#
# Word: i
#   Position: x1=1380, y1=608, x2=1383, y2=638
#     Letter: i, Color: (153, 191, 228), Style: Regular
#
#
# Word: t
#   Position: x1=1380, y1=608, x2=1405, y2=638
#     Letter: t, Color: (104, 130, 155), Style: Regular
#
#
# Word: i
#   Position: x1=1417, y1=608, x2=1424, y2=638
#     Letter: i, Color: (58, 72, 87), Style: Regular
#
#
# Word: s
#   Position: x1=1427, y1=608, x2=1445, y2=630
#     Letter: s, Color: (97, 121, 146), Style: Regular
#
#
# Word: t
#   Position: x1=1456, y1=608, x2=1471, y2=634
#     Letter: t, Color: (99, 124, 151), Style: Regular
#
#
# Word: r
#   Position: x1=1474, y1=608, x2=1488, y2=629
#     Letter: r, Color: (96, 120, 147), Style: Regular
#
#
# Word: a
#   Position: x1=1490, y1=608, x2=1510, y2=630
#     Letter: a, Color: (103, 128, 158), Style: Regular
#
#
# Word: i
#   Position: x1=1513, y1=608, x2=1519, y2=638
#     Letter: i, Color: (84, 105, 130), Style: Regular
#
#
# Word: n
#   Position: x1=1525, y1=608, x2=1544, y2=630
#     Letter: n, Color: (99, 123, 153), Style: Regular
#
#
# Word: e
#   Position: x1=1548, y1=608, x2=1568, y2=630
#     Letter: e, Color: (106, 133, 166), Style: Regular
#
#
# Word: d
#   Position: x1=1571, y1=608, x2=1592, y2=638
#     Letter: d, Color: (96, 120, 152), Style: Regular
#
#
# Word: t
#   Position: x1=1605, y1=608, x2=1620, y2=634
#     Letter: t, Color: (101, 126, 160), Style: Regular
#
#
# Word: o
#   Position: x1=1622, y1=607, x2=1643, y2=630
#     Letter: o, Color: (96, 121, 154), Style: Regular
#
#
# Word: i
#   Position: x1=1657, y1=608, x2=1663, y2=638
#     Letter: i, Color: (115, 144, 185), Style: Regular
#
#
# Word: d
#   Position: x1=1667, y1=607, x2=1688, y2=638
#     Letter: d, Color: (99, 124, 160), Style: Regular
#
#
# Word: e
#   Position: x1=1693, y1=607, x2=1712, y2=630
#     Letter: e, Color: (107, 134, 175), Style: Regular
#
#
# Word: n
#   Position: x1=1717, y1=608, x2=1736, y2=630
#     Letter: n, Color: (129, 162, 212), Style: Regular
#
#
# Word: t
#   Position: x1=1727, y1=599, x2=1743, y2=638
#     Letter: t, Color: (117, 147, 193), Style: Regular
#
#
# Word: i
#   Position: x1=1739, y1=607, x2=1754, y2=634
#     Letter: i, Color: (94, 118, 156), Style: Regular
#
#
# Word: f
#   Position: x1=1757, y1=608, x2=1764, y2=638
#     Letter: f, Color: (104, 129, 171), Style: Regular
#
#
# Word: y
#   Position: x1=1767, y1=599, x2=1804, y2=638
#     Letter: y, Color: (112, 141, 187), Style: Regular
#
#
# Word: .
#   Position: x1=1806, y1=608, x2=1813, y2=614
#     Letter: ., Color: (151, 189, 252), Style: Regular
#
#
# Word: F
#   Position: x1=780, y1=499, x2=797, y2=527
#     Letter: F, Color: (181, 226, 232), Style: Regular
#
#
# Word: a
#   Position: x1=800, y1=499, x2=820, y2=520
#     Letter: a, Color: (180, 225, 232), Style: Regular
#
#
# Word: l
#   Position: x1=824, y1=499, x2=832, y2=529
#     Letter: l, Color: (180, 224, 232), Style: Regular
#
#
# Word: s
#   Position: x1=834, y1=499, x2=851, y2=520
#     Letter: s, Color: (179, 224, 233), Style: Regular
#
#
# Word: e
#   Position: x1=854, y1=499, x2=874, y2=520
#     Letter: e, Color: (179, 223, 233), Style: Regular
#
#
# Word: P
#   Position: x1=888, y1=499, x2=909, y2=527
#     Letter: P, Color: (178, 222, 234), Style: Regular
#
#
# Word: o
#   Position: x1=905, y1=499, x2=921, y2=529
#     Letter: o, Color: (177, 221, 234), Style: Regular
#
#
# Word: s
#   Position: x1=912, y1=499, x2=933, y2=520
#     Letter: s, Color: (177, 221, 234), Style: Regular
#
#
# Word: i
#   Position: x1=936, y1=499, x2=953, y2=520
#     Letter: i, Color: (176, 220, 235), Style: Regular
#
#
# Word: t
#   Position: x1=957, y1=499, x2=982, y2=529
#     Letter: t, Color: (176, 219, 235), Style: Regular
#
#
# Word: i
#   Position: x1=985, y1=499, x2=991, y2=529
#     Letter: i, Color: (175, 219, 236), Style: Regular
#
#
# Word: v
#   Position: x1=994, y1=499, x2=1016, y2=520
#     Letter: v, Color: (175, 218, 236), Style: Regular
#
#
# Word: e
#   Position: x1=1018, y1=499, x2=1038, y2=520
#     Letter: e, Color: (174, 217, 236), Style: Regular
#
#
# Word: s
#   Position: x1=1040, y1=499, x2=1057, y2=520
#     Letter: s, Color: (173, 216, 237), Style: Regular
#
#
# Word: (
#   Position: x1=1071, y1=495, x2=1081, y2=529
#     Letter: (, Color: (173, 215, 237), Style: Regular
#
#
# Word: F
#   Position: x1=1085, y1=499, x2=1103, y2=527
#     Letter: F, Color: (172, 215, 238), Style: Regular
#
#
# Word: P
#   Position: x1=1108, y1=499, x2=1128, y2=527
#     Letter: P, Color: (171, 214, 238), Style: Regular
#
#
# Word: )
#   Position: x1=1131, y1=495, x2=1141, y2=529
#     Letter: ), Color: (171, 213, 239), Style: Regular
#
#
# Word: I
#   Position: x1=126, y1=444, x2=131, y2=472
#     Letter: I, Color: (165, 205, 179), Style: Regular
#
#
# Word: n
#   Position: x1=138, y1=444, x2=157, y2=466
#     Letter: n, Color: (134, 167, 147), Style: Regular
#
#
# Word: s
#   Position: x1=161, y1=444, x2=178, y2=466
#     Letter: s, Color: (136, 169, 149), Style: Regular
#
#
# Word: t
#   Position: x1=180, y1=444, x2=195, y2=470
#     Letter: t, Color: (128, 160, 141), Style: Regular
#
#
# Word: a
#   Position: x1=197, y1=444, x2=217, y2=466
#     Letter: a, Color: (127, 158, 141), Style: Regular
#
#
# Word: n
#   Position: x1=221, y1=444, x2=240, y2=466
#     Letter: n, Color: (121, 150, 134), Style: Regular
#
#
# Word: c
#   Position: x1=244, y1=444, x2=264, y2=466
#     Letter: c, Color: (125, 155, 140), Style: Regular
#
#
# Word: e
#   Position: x1=258, y1=444, x2=274, y2=472
#     Letter: e, Color: (126, 157, 142), Style: Regular
#
#
# Word: s
#   Position: x1=266, y1=444, x2=306, y2=466
#     Letter: s, Color: (149, 186, 169), Style: Regular
#
#
# Word: i
#   Position: x1=318, y1=444, x2=325, y2=474
#     Letter: i, Color: (103, 128, 117), Style: Regular
#
#
# Word: n
#   Position: x1=330, y1=444, x2=349, y2=466
#     Letter: n, Color: (132, 165, 151), Style: Regular
#
#
# Word: c
#   Position: x1=354, y1=444, x2=373, y2=466
#     Letter: c, Color: (115, 143, 132), Style: Regular
#
#
# Word: o
#   Position: x1=376, y1=444, x2=396, y2=466
#     Letter: o, Color: (115, 143, 133), Style: Regular
#
#
# Word: r
#   Position: x1=401, y1=444, x2=415, y2=465
#     Letter: r, Color: (116, 144, 135), Style: Regular
#
#
# Word: r
#   Position: x1=418, y1=444, x2=431, y2=465
#     Letter: r, Color: (113, 141, 132), Style: Regular
#
#
# Word: e
#   Position: x1=433, y1=444, x2=453, y2=466
#     Letter: e, Color: (133, 166, 156), Style: Regular
#
#
# Word: c
#   Position: x1=456, y1=444, x2=475, y2=466
#     Letter: c, Color: (113, 140, 133), Style: Regular
#
#
# Word: t
#   Position: x1=477, y1=444, x2=492, y2=470
#     Letter: t, Color: (99, 124, 118), Style: Regular
#
#
# Word: l
#   Position: x1=496, y1=444, x2=504, y2=474
#     Letter: l, Color: (190, 236, 226), Style: Regular
#
#
# Word: y
#   Position: x1=505, y1=435, x2=527, y2=465
#     Letter: y, Color: (127, 159, 152), Style: Regular
#
#
# Word: p
#   Position: x1=540, y1=435, x2=560, y2=466
#     Letter: p, Color: (141, 175, 169), Style: Regular
#
#
# Word: r
#   Position: x1=565, y1=444, x2=578, y2=465
#     Letter: r, Color: (180, 224, 218), Style: Regular
#
#
# Word: e
#   Position: x1=580, y1=444, x2=600, y2=466
#     Letter: e, Color: (116, 145, 141), Style: Regular
#
#
# Word: d
#   Position: x1=603, y1=444, x2=624, y2=474
#     Letter: d, Color: (93, 115, 113), Style: Regular
#
#
# Word: i
#   Position: x1=629, y1=444, x2=636, y2=474
#     Letter: i, Color: (95, 119, 117), Style: Regular
#
#
# Word: c
#   Position: x1=640, y1=444, x2=659, y2=466
#     Letter: c, Color: (122, 152, 150), Style: Regular
#
#
# Word: t
#   Position: x1=661, y1=444, x2=676, y2=470
#     Letter: t, Color: (107, 133, 132), Style: Regular
#
#
# Word: e
#   Position: x1=678, y1=444, x2=698, y2=466
#     Letter: e, Color: (123, 153, 153), Style: Regular
#
#
# Word: d
#   Position: x1=701, y1=444, x2=722, y2=474
#     Letter: d, Color: (123, 153, 154), Style: Regular
#
#
# Word: a
#   Position: x1=736, y1=444, x2=756, y2=466
#     Letter: a, Color: (149, 185, 188), Style: Regular
#
#
# Word: s
#   Position: x1=757, y1=444, x2=774, y2=466
#     Letter: s, Color: (129, 160, 163), Style: Regular
#
#
# Word: p
#   Position: x1=788, y1=435, x2=808, y2=466
#     Letter: p, Color: (141, 176, 181), Style: Regular
#
#
# Word: o
#   Position: x1=812, y1=444, x2=833, y2=466
#     Letter: o, Color: (93, 116, 120), Style: Regular
#
#
# Word: s
#   Position: x1=836, y1=444, x2=853, y2=466
#     Letter: s, Color: (110, 137, 143), Style: Regular
#
#
# Word: i
#   Position: x1=857, y1=444, x2=863, y2=474
#     Letter: i, Color: (175, 219, 228), Style: Regular
#
#
# Word: t
#   Position: x1=866, y1=444, x2=881, y2=470
#     Letter: t, Color: (118, 147, 154), Style: Regular
#
#
# Word: i
#   Position: x1=884, y1=444, x2=891, y2=474
#     Letter: i, Color: (84, 105, 111), Style: Regular
#
#
# Word: v
#   Position: x1=894, y1=444, x2=915, y2=465
#     Letter: v, Color: (93, 116, 123), Style: Regular
#
#
# Word: e
#   Position: x1=918, y1=444, x2=937, y2=466
#     Letter: e, Color: (107, 134, 142), Style: Regular
#
#
# Word: b
#   Position: x1=951, y1=444, x2=972, y2=474
#     Letter: b, Color: (124, 154, 165), Style: Regular
#
#
# Word: y
#   Position: x1=974, y1=435, x2=996, y2=465
#     Letter: y, Color: (138, 172, 186), Style: Italic
#
#
# Word: t
#   Position: x1=1006, y1=444, x2=1021, y2=470
#     Letter: t, Color: (100, 125, 135), Style: Regular
#
#
# Word: h
#   Position: x1=1025, y1=444, x2=1044, y2=474
#     Letter: h, Color: (111, 138, 151), Style: Regular
#
#
# Word: e
#   Position: x1=1049, y1=444, x2=1068, y2=466
#     Letter: e, Color: (118, 147, 162), Style: Regular
#
#
# Word: m
#   Position: x1=1082, y1=444, x2=1113, y2=466
#     Letter: m, Color: (115, 144, 159), Style: Italic
#
#
# Word: o
#   Position: x1=1117, y1=444, x2=1138, y2=466
#     Letter: o, Color: (139, 173, 194), Style: Regular
#
#
# Word: d
#   Position: x1=1130, y1=444, x2=1150, y2=474
#     Letter: d, Color: (121, 151, 169), Style: Regular
#
#
# Word: e
#   Position: x1=1142, y1=444, x2=1162, y2=474
#     Letter: e, Color: (117, 145, 164), Style: Regular
#
#
# Word: l
#   Position: x1=1167, y1=444, x2=1187, y2=466
#     Letter: l, Color: (154, 192, 217), Style: Regular
#
#
# Word: .
#   Position: x1=1191, y1=444, x2=1209, y2=474
#     Letter: ., Color: (121, 151, 172), Style: Regular
#
#
# Word: T
#   Position: x1=1221, y1=444, x2=1243, y2=472
#     Letter: T, Color: (104, 130, 149), Style: Regular
#
#
# Word: h
#   Position: x1=1247, y1=444, x2=1266, y2=474
#     Letter: h, Color: (99, 124, 143), Style: Regular
#
#
# Word: e
#   Position: x1=1270, y1=444, x2=1290, y2=466
#     Letter: e, Color: (79, 98, 114), Style: Regular
#
#
# Word: s
#   Position: x1=1292, y1=444, x2=1310, y2=466
#     Letter: s, Color: (105, 132, 154), Style: Regular
#
#
# Word: e
#   Position: x1=1313, y1=444, x2=1332, y2=466
#     Letter: e, Color: (103, 128, 151), Style: Regular
#
#
# Word: a
#   Position: x1=1345, y1=444, x2=1365, y2=466
#     Letter: a, Color: (97, 122, 144), Style: Regular
#
#
# Word: r
#   Position: x1=1368, y1=444, x2=1382, y2=465
#     Letter: r, Color: (153, 192, 228), Style: Regular
#
#
# Word: e
#   Position: x1=1384, y1=444, x2=1403, y2=466
#     Letter: e, Color: (91, 114, 136), Style: Regular
#
#
# Word: i
#   Position: x1=1416, y1=444, x2=1423, y2=474
#     Letter: i, Color: (65, 81, 98), Style: Regular
#
#
# Word: n
#   Position: x1=1428, y1=444, x2=1448, y2=466
#     Letter: n, Color: (108, 135, 164), Style: Regular
#
#
# Word: s
#   Position: x1=1451, y1=444, x2=1469, y2=466
#     Letter: s, Color: (104, 131, 159), Style: Regular
#
#
# Word: t
#   Position: x1=1470, y1=444, x2=1486, y2=470
#     Letter: t, Color: (110, 137, 168), Style: Regular
#
#
# Word: a
#   Position: x1=1488, y1=444, x2=1508, y2=466
#     Letter: a, Color: (98, 123, 151), Style: Regular
#
#
# Word: n
#   Position: x1=1511, y1=444, x2=1530, y2=466
#     Letter: n, Color: (90, 112, 139), Style: Regular
#
#
# Word: c
#   Position: x1=1535, y1=444, x2=1554, y2=466
#     Letter: c, Color: (99, 124, 154), Style: Regular
#
#
# Word: e
#   Position: x1=1557, y1=443, x2=1576, y2=466
#     Letter: e, Color: (104, 130, 163), Style: Regular
#
#
# Word: s
#   Position: x1=1579, y1=443, x2=1596, y2=466
#     Letter: s, Color: (94, 117, 148), Style: Regular
#
#
# Word: w
#   Position: x1=1607, y1=444, x2=1637, y2=465
#     Letter: w, Color: (97, 122, 155), Style: Regular
#
#
# Word: h
#   Position: x1=1640, y1=444, x2=1660, y2=474
#     Letter: h, Color: (129, 161, 206), Style: Regular
#
#
# Word: e
#   Position: x1=1654, y1=443, x2=1674, y2=474
#     Letter: e, Color: (94, 117, 151), Style: Regular
#
#
# Word: r
#   Position: x1=1664, y1=443, x2=1684, y2=466
#     Letter: r, Color: (103, 129, 167), Style: Regular
#
#
# Word: e
#   Position: x1=1688, y1=443, x2=1723, y2=466
#     Letter: e, Color: (102, 127, 166), Style: Italic
#
#
# Word: t
#   Position: x1=1734, y1=443, x2=1750, y2=470
#     Letter: t, Color: (88, 110, 145), Style: Regular
#
#
# Word: h
#   Position: x1=1753, y1=444, x2=1772, y2=474
#     Letter: h, Color: (95, 119, 158), Style: Regular
#
#
# Word: e
#   Position: x1=1777, y1=443, x2=1797, y2=466
#     Letter: e, Color: (105, 132, 175), Style: Regular
#
#
# Word: m
#   Position: x1=133, y1=390, x2=164, y2=412
#     Letter: m, Color: (118, 147, 129), Style: Regular
#
#
# Word: o
#   Position: x1=169, y1=390, x2=189, y2=412
#     Letter: o, Color: (122, 152, 134), Style: Regular
#
#
# Word: d
#   Position: x1=181, y1=390, x2=201, y2=420
#     Letter: d, Color: (121, 151, 133), Style: Regular
#
#
# Word: e
#   Position: x1=193, y1=390, x2=214, y2=420
#     Letter: e, Color: (121, 151, 134), Style: Regular
#
#
# Word: l
#   Position: x1=219, y1=390, x2=251, y2=420
#     Letter: l, Color: (123, 153, 137), Style: Regular
#
#
# Word: e
#   Position: x1=263, y1=390, x2=282, y2=412
#     Letter: e, Color: (135, 168, 152), Style: Regular
#
#
# Word: r
#   Position: x1=287, y1=390, x2=300, y2=411
#     Letter: r, Color: (138, 172, 156), Style: Regular
#
#
# Word: r
#   Position: x1=303, y1=390, x2=317, y2=411
#     Letter: r, Color: (128, 160, 146), Style: Regular
#
#
# Word: o
#   Position: x1=319, y1=390, x2=340, y2=412
#     Letter: o, Color: (140, 174, 159), Style: Regular
#
#
# Word: n
#   Position: x1=344, y1=390, x2=364, y2=412
#     Letter: n, Color: (139, 174, 160), Style: Regular
#
#
# Word: e
#   Position: x1=368, y1=390, x2=388, y2=412
#     Letter: e, Color: (119, 148, 137), Style: Regular
#
#
# Word: o
#   Position: x1=381, y1=381, x2=401, y2=420
#     Letter: o, Color: (141, 175, 163), Style: Regular
#
#
# Word: u
#   Position: x1=391, y1=390, x2=412, y2=412
#     Letter: u, Color: (123, 154, 143), Style: Regular
#
#
# Word: s
#   Position: x1=416, y1=390, x2=435, y2=411
#     Letter: s, Color: (125, 156, 146), Style: Regular
#
#
# Word: l
#   Position: x1=439, y1=390, x2=456, y2=412
# ...
#     Letter: e, Color: (155, 193, 201), Style: Regular
#
#
# Word: N
#   Position: x1=877, y1=226, x2=901, y2=254
#     Letter: N, Color: (103, 129, 136), Style: Regular
#
#
# Word: e
#   Position: x1=906, y1=226, x2=926, y2=247
#     Letter: e, Color: (117, 146, 154), Style: Regular
#
#
# Word: g
#   Position: x1=928, y1=217, x2=949, y2=250
#     Letter: g, Color: (137, 170, 181), Style: Regular
#
#
# Word: a
#   Position: x1=941, y1=217, x2=961, y2=256
#     Letter: a, Color: (140, 175, 186), Style: Regular
#
#
# Word: t
#   Position: x1=951, y1=226, x2=971, y2=247
#     Letter: t, Color: (117, 146, 157), Style: Regular
#
#
# Word: i
#   Position: x1=972, y1=226, x2=997, y2=256
#     Letter: i, Color: (116, 145, 156), Style: Italic
#
#
# Word: v
#   Position: x1=1000, y1=226, x2=1022, y2=247
#     Letter: v, Color: (116, 145, 157), Style: Regular
#
#
# Word: e
#   Position: x1=1024, y1=226, x2=1043, y2=247
#     Letter: e, Color: (109, 136, 148), Style: Regular
#
#
# Word: s
#   Position: x1=1046, y1=226, x2=1063, y2=247
#     Letter: s, Color: (98, 122, 134), Style: Regular
#
#
# Word: (
#   Position: x1=1077, y1=222, x2=1086, y2=256
#     Letter: (, Color: (110, 137, 151), Style: Italic
#
#
# Word: F
#   Position: x1=1091, y1=226, x2=1109, y2=254
#     Letter: F, Color: (112, 139, 155), Style: Regular
#
#
# Word: N
#   Position: x1=1114, y1=226, x2=1137, y2=254
#     Letter: N, Color: (137, 171, 190), Style: Regular
#
#
# Word: )
#   Position: x1=1142, y1=222, x2=1152, y2=256
#     Letter: ), Color: (128, 160, 180), Style: Regular
#
#
# Word: I
#   Position: x1=93, y1=172, x2=99, y2=200
#     Letter: I, Color: (202, 251, 217), Style: Regular
#
#
# Word: n
#   Position: x1=105, y1=172, x2=125, y2=194
#     Letter: n, Color: (119, 149, 129), Style: Regular
#
#
# Word: s
#   Position: x1=128, y1=172, x2=146, y2=194
#     Letter: s, Color: (127, 158, 138), Style: Regular
#
#
# Word: t
#   Position: x1=147, y1=172, x2=163, y2=198
#     Letter: t, Color: (118, 147, 129), Style: Regular
#
#
# Word: a
#   Position: x1=165, y1=172, x2=185, y2=194
#     Letter: a, Color: (143, 178, 157), Style: Regular
#
#
# Word: n
#   Position: x1=188, y1=172, x2=207, y2=194
#     Letter: n, Color: (130, 162, 143), Style: Regular
#
#
# Word: c
#   Position: x1=205, y1=172, x2=221, y2=200
#     Letter: c, Color: (138, 172, 153), Style: Regular
#
#
# Word: e
#   Position: x1=212, y1=172, x2=231, y2=194
#     Letter: e, Color: (124, 155, 138), Style: Regular
#
#
# Word: s
#   Position: x1=234, y1=172, x2=273, y2=194
#     Letter: s, Color: (132, 164, 148), Style: Regular
#
#
# Word: i
#   Position: x1=286, y1=172, x2=292, y2=202
#     Letter: i, Color: (196, 244, 221), Style: Regular
#
#
# Word: n
#   Position: x1=298, y1=172, x2=317, y2=194
#     Letter: n, Color: (125, 156, 142), Style: Regular
#
#
# Word: c
#   Position: x1=322, y1=172, x2=341, y2=194
#     Letter: c, Color: (148, 185, 170), Style: Regular
#
#
# Word: o
#   Position: x1=343, y1=172, x2=364, y2=194
#     Letter: o, Color: (140, 175, 161), Style: Regular
#
#
# Word: r
#   Position: x1=369, y1=172, x2=382, y2=193
#     Letter: r, Color: (140, 174, 161), Style: Regular
#
#
# Word: r
#   Position: x1=385, y1=172, x2=399, y2=193
#     Letter: r, Color: (121, 151, 140), Style: Regular
#
#
# Word: e
#   Position: x1=401, y1=172, x2=420, y2=194
#     Letter: e, Color: (114, 142, 133), Style: Regular
#
#
# Word: c
#   Position: x1=424, y1=172, x2=443, y2=194
#     Letter: c, Color: (117, 146, 137), Style: Regular
#
#
# Word: t
#   Position: x1=444, y1=172, x2=460, y2=198
#     Letter: t, Color: (99, 123, 116), Style: Regular
#
#
# Word: l
#   Position: x1=463, y1=172, x2=472, y2=202
#     Letter: l, Color: (81, 101, 96), Style: Regular
#
#
# Word: y
#   Position: x1=473, y1=163, x2=495, y2=193
#     Letter: y, Color: (148, 184, 175), Style: Regular
#
#
# Word: p
#   Position: x1=507, y1=163, x2=528, y2=194
#     Letter: p, Color: (135, 168, 161), Style: Regular
#
#
# Word: r
#   Position: x1=532, y1=172, x2=546, y2=193
#     Letter: r, Color: (120, 150, 144), Style: Regular
#
#
# Word: e
#   Position: x1=548, y1=172, x2=568, y2=194
#     Letter: e, Color: (111, 138, 134), Style: Regular
#
#
# Word: d
#   Position: x1=571, y1=172, x2=592, y2=202
#     Letter: d, Color: (96, 119, 116), Style: Regular
#
#
# Word: i
#   Position: x1=597, y1=172, x2=603, y2=202
#     Letter: i, Color: (82, 102, 100), Style: Regular
#
#
# Word: c
#   Position: x1=608, y1=172, x2=627, y2=194
#     Letter: c, Color: (127, 158, 155), Style: Regular
#
#
# Word: t
#   Position: x1=628, y1=172, x2=643, y2=198
#     Letter: t, Color: (104, 130, 128), Style: Regular
#
#
# Word: e
#   Position: x1=646, y1=172, x2=665, y2=194
#     Letter: e, Color: (108, 135, 134), Style: Regular
#
#
# Word: d
#   Position: x1=669, y1=172, x2=689, y2=202
#     Letter: d, Color: (98, 123, 122), Style: Italic
#
#
# Word: a
#   Position: x1=703, y1=172, x2=723, y2=194
#     Letter: a, Color: (112, 140, 141), Style: Regular
#
#
# Word: s
#   Position: x1=725, y1=172, x2=742, y2=194
#     Letter: s, Color: (115, 143, 144), Style: Regular
#
#
# Word: n
#   Position: x1=756, y1=172, x2=775, y2=194
#     Letter: n, Color: (107, 133, 136), Style: Regular
#
#
# Word: e
#   Position: x1=779, y1=172, x2=799, y2=194
#     Letter: e, Color: (118, 147, 150), Style: Regular
#
#
# Word: g
#   Position: x1=801, y1=163, x2=822, y2=196
#     Letter: g, Color: (136, 170, 175), Style: Regular
#
#
# Word: a
#   Position: x1=824, y1=172, x2=844, y2=194
#     Letter: a, Color: (88, 110, 115), Style: Regular
#
#
# Word: t
#   Position: x1=845, y1=172, x2=860, y2=198
#     Letter: t, Color: (106, 133, 138), Style: Regular
#
#
# Word: i
#   Position: x1=863, y1=172, x2=870, y2=202
#     Letter: i, Color: (124, 154, 161), Style: Regular
#
#
# Word: v
#   Position: x1=873, y1=172, x2=894, y2=193
#     Letter: v, Color: (118, 148, 155), Style: Regular
#
#
# Word: e
#   Position: x1=897, y1=172, x2=916, y2=194
#     Letter: e, Color: (141, 176, 186), Style: Regular
#
#
# Word: b
#   Position: x1=930, y1=172, x2=951, y2=202
#     Letter: b, Color: (116, 144, 154), Style: Regular
#
#
# Word: y
#   Position: x1=953, y1=163, x2=975, y2=193
#     Letter: y, Color: (156, 195, 209), Style: Regular
#
#
# Word: t
#   Position: x1=985, y1=172, x2=1000, y2=198
#     Letter: t, Color: (97, 122, 131), Style: Regular
#
#
# Word: h
#   Position: x1=1004, y1=172, x2=1023, y2=202
#     Letter: h, Color: (112, 140, 152), Style: Regular
#
#
# Word: e
#   Position: x1=1027, y1=172, x2=1047, y2=194
#     Letter: e, Color: (138, 173, 189), Style: Regular
#
#
# Word: m
#   Position: x1=1061, y1=172, x2=1092, y2=194
#     Letter: m, Color: (106, 132, 146), Style: Regular
#
#
# Word: o
#   Position: x1=1096, y1=172, x2=1117, y2=194
#     Letter: o, Color: (109, 136, 151), Style: Regular
#
#
# Word: d
#   Position: x1=1109, y1=172, x2=1129, y2=202
#     Letter: d, Color: (95, 119, 133), Style: Regular
#
#
# Word: e
#   Position: x1=1121, y1=172, x2=1141, y2=202
#     Letter: e, Color: (97, 121, 135), Style: Regular
#
#
# Word: l
#   Position: x1=1146, y1=172, x2=1166, y2=194
#     Letter: l, Color: (92, 115, 129), Style: Regular
#
#
# Word: .
#   Position: x1=1170, y1=172, x2=1188, y2=202
#     Letter: ., Color: (159, 198, 224), Style: Regular
#
#
# Word: T
#   Position: x1=1200, y1=172, x2=1222, y2=200
#     Letter: T, Color: (87, 108, 124), Style: Regular
#
#
# Word: h
#   Position: x1=1225, y1=172, x2=1245, y2=202
#     Letter: h, Color: (109, 136, 156), Style: Regular
#
#
# Word: e
#   Position: x1=1249, y1=172, x2=1269, y2=194
#     Letter: e, Color: (111, 138, 160), Style: Regular
#
#
# Word: s
#   Position: x1=1271, y1=172, x2=1289, y2=194
#     Letter: s, Color: (105, 131, 152), Style: Regular
#
#
# Word: e
#   Position: x1=1292, y1=172, x2=1311, y2=194
#     Letter: e, Color: (133, 166, 194), Style: Regular
#
#
# Word: a
#   Position: x1=1324, y1=172, x2=1344, y2=194
#     Letter: a, Color: (100, 124, 147), Style: Regular
#
#
# Word: r
#   Position: x1=1347, y1=172, x2=1361, y2=193
#     Letter: r, Color: (108, 135, 160), Style: Regular
#
#
# Word: e
#   Position: x1=1363, y1=172, x2=1382, y2=194
#     Letter: e, Color: (131, 164, 195), Style: Regular
#
#
# Word: c
#   Position: x1=1395, y1=172, x2=1414, y2=194
#     Letter: c, Color: (122, 152, 182), Style: Regular
#
#
# Word: a
#   Position: x1=1416, y1=172, x2=1437, y2=194
#     Letter: a, Color: (104, 129, 156), Style: Regular
#
#
# Word: s
#   Position: x1=1438, y1=172, x2=1455, y2=194
#     Letter: s, Color: (102, 127, 155), Style: Regular
#
#
# Word: e
#   Position: x1=1458, y1=172, x2=1478, y2=194
#     Letter: e, Color: (107, 133, 163), Style: Regular
#
#
# Word: s
#   Position: x1=1481, y1=172, x2=1498, y2=194
#     Letter: s, Color: (135, 169, 207), Style: Regular
#
#
# Word: w
#   Position: x1=1509, y1=172, x2=1538, y2=193
#     Letter: w, Color: (86, 108, 133), Style: Regular
#
#
# Word: h
#   Position: x1=1542, y1=172, x2=1561, y2=202
#     Letter: h, Color: (103, 129, 161), Style: Regular
#
#
# Word: e
#   Position: x1=1553, y1=171, x2=1573, y2=202
#     Letter: e, Color: (96, 120, 150), Style: Regular
#
#
# Word: r
#   Position: x1=1566, y1=171, x2=1603, y2=194
#     Letter: r, Color: (105, 131, 165), Style: Regular
#
#
# Word: e
#   Position: x1=1605, y1=171, x2=1625, y2=194
#     Letter: e, Color: (127, 158, 201), Style: Regular
#
#
# Word: t
#   Position: x1=1636, y1=171, x2=1651, y2=198
#     Letter: t, Color: (87, 109, 139), Style: Regular
#
#
# Word: h
#   Position: x1=1655, y1=172, x2=1674, y2=202
#     Letter: h, Color: (100, 125, 160), Style: Regular
#
#
# Word: e
#   Position: x1=1679, y1=171, x2=1698, y2=194
#     Letter: e, Color: (125, 157, 203), Style: Regular
#
#
# Word: m
#   Position: x1=1712, y1=172, x2=1743, y2=194
#     Letter: m, Color: (94, 118, 154), Style: Regular
#
#
# Word: o
#   Position: x1=1747, y1=171, x2=1768, y2=194
#     Letter: o, Color: (100, 125, 165), Style: Regular
#
#
# Word: d
#   Position: x1=1772, y1=171, x2=1792, y2=202
#     Letter: d, Color: (87, 109, 145), Style: Regular
#
#
# Word: e
#   Position: x1=1785, y1=171, x2=1805, y2=202
#     Letter: e, Color: (90, 113, 150), Style: Regular
#
#
# Word: l
#   Position: x1=1797, y1=171, x2=1830, y2=202
#     Letter: l, Color: (107, 134, 180), Style: Regular
#
#
# Word: f
#   Position: x1=300, y1=117, x2=316, y2=147
#     Letter: f, Color: (195, 243, 222), Style: Regular
#
#
# Word: a
#   Position: x1=317, y1=117, x2=337, y2=139
#     Letter: a, Color: (195, 243, 222), Style: Regular
#
#
# Word: i
#   Position: x1=340, y1=117, x2=346, y2=147
#     Letter: i, Color: (194, 242, 222), Style: Regular
#
#
# Word: l
#   Position: x1=351, y1=117, x2=360, y2=147
#     Letter: l, Color: (194, 242, 223), Style: Regular
#
#
# Word: s
#   Position: x1=362, y1=117, x2=379, y2=139
#     Letter: s, Color: (194, 241, 223), Style: Regular
#
#
# Word: t
#   Position: x1=390, y1=117, x2=405, y2=143
#     Letter: t, Color: (193, 240, 224), Style: Regular
#
#
# Word: o
#   Position: x1=408, y1=117, x2=428, y2=139
#     Letter: o, Color: (192, 239, 224), Style: Regular
#
#
# Word: i
#   Position: x1=442, y1=117, x2=473, y2=147
#     Letter: i, Color: (191, 238, 225), Style: Regular
#
#
# Word: d
#   Position: x1=464, y1=108, x2=480, y2=147
#     Letter: d, Color: (191, 237, 225), Style: Regular
#
#
# Word: e
#   Position: x1=478, y1=117, x2=498, y2=139
#     Letter: e, Color: (190, 237, 225), Style: Regular
#
#
# Word: n
#   Position: x1=502, y1=117, x2=521, y2=139
#     Letter: n, Color: (189, 236, 226), Style: Regular
#
#
# Word: t
#   Position: x1=525, y1=117, x2=540, y2=143
#     Letter: t, Color: (189, 235, 226), Style: Regular
#
#
# Word: i
#   Position: x1=543, y1=117, x2=549, y2=147
#     Letter: i, Color: (188, 235, 227), Style: Regular
#
#
# Word: f
#   Position: x1=552, y1=117, x2=568, y2=147
#     Letter: f, Color: (188, 234, 227), Style: Regular
#
#
# Word: y
#   Position: x1=568, y1=108, x2=589, y2=138
#     Letter: y, Color: (187, 233, 227), Style: Regular
#
#
# Word: t
#   Position: x1=600, y1=117, x2=615, y2=143
#     Letter: t, Color: (186, 232, 228), Style: Regular
#
#
# Word: h
#   Position: x1=618, y1=117, x2=638, y2=147
#     Letter: h, Color: (186, 232, 228), Style: Regular
#
#
# Word: e
#   Position: x1=642, y1=117, x2=661, y2=139
#     Letter: e, Color: (185, 231, 229), Style: Regular
#
#
# Word: a
#   Position: x1=674, y1=117, x2=694, y2=139
#     Letter: a, Color: (184, 230, 229), Style: Regular
#
#
# Word: c
#   Position: x1=696, y1=117, x2=715, y2=139
#     Letter: c, Color: (184, 229, 230), Style: Regular
#
#
# Word: t
#   Position: x1=717, y1=117, x2=732, y2=143
#     Letter: t, Color: (183, 228, 230), Style: Italic
#
#
# Word: u
#   Position: x1=735, y1=117, x2=754, y2=138
#     Letter: u, Color: (182, 227, 231), Style: Regular
#
#
# Word: a
#   Position: x1=759, y1=117, x2=779, y2=139
#     Letter: a, Color: (182, 226, 231), Style: Italic
#
#
# Word: l
#   Position: x1=782, y1=117, x2=791, y2=147
#     Letter: l, Color: (167, 194, 232), Style: Regular
#
#
# Word: p
#   Position: x1=804, y1=108, x2=824, y2=139
#     Letter: p, Color: (164, 186, 232), Style: Regular
#
#
# Word: r
#   Position: x1=829, y1=117, x2=843, y2=138
#     Letter: r, Color: (155, 166, 233), Style: Regular
#
#
# Word: e
#   Position: x1=845, y1=117, x2=864, y2=139
#     Letter: e, Color: (147, 147, 233), Style: Regular
#
#
# Word: s
#   Position: x1=867, y1=117, x2=884, y2=139
#     Letter: s, Color: (168, 197, 233), Style: Regular
#
#
# Word: e
#   Position: x1=887, y1=117, x2=907, y2=139
#     Letter: e, Color: (145, 144, 234), Style: Regular
#
#
# Word: n
#   Position: x1=911, y1=117, x2=930, y2=139
#     Letter: n, Color: (152, 162, 234), Style: Regular
#
#
# Word: c
#   Position: x1=935, y1=117, x2=954, y2=139
#     Letter: c, Color: (144, 144, 235), Style: Regular
#
#
# Word: e
#   Position: x1=957, y1=117, x2=976, y2=139
#     Letter: e, Color: (147, 152, 235), Style: Regular
#
#
# Word: o
#   Position: x1=989, y1=117, x2=1009, y2=139
#     Letter: o, Color: (146, 148, 235), Style: Regular
#
#
# Word: f
#   Position: x1=1012, y1=117, x2=1028, y2=147
#     Letter: f, Color: (135, 124, 235), Style: Regular
#
#
# Word: t
#   Position: x1=1037, y1=117, x2=1074, y2=147
#     Letter: t, Color: (148, 154, 236), Style: Regular
#
#
# Word: h
#   Position: x1=1068, y1=117, x2=1088, y2=147
#     Letter: h, Color: (142, 141, 236), Style: Regular
#
#
# Word: e
#   Position: x1=1079, y1=117, x2=1098, y2=139
#     Letter: e, Color: (138, 130, 236), Style: Italic
#
#
# Word: p
#   Position: x1=1112, y1=108, x2=1157, y2=147
#     Letter: p, Color: (158, 182, 238), Style: Regular
#
#
# Word: h
#   Position: x1=1161, y1=117, x2=1181, y2=139
#     Letter: h, Color: (170, 212, 239), Style: Regular
#
#
# Word: e
#   Position: x1=1172, y1=108, x2=1192, y2=147
#     Letter: e, Color: (169, 211, 240), Style: Regular
#
#
# Word: n
#   Position: x1=1185, y1=117, x2=1204, y2=139
#     Letter: n, Color: (169, 211, 240), Style: Regular
#
#
# Word: o
#   Position: x1=1209, y1=117, x2=1230, y2=139
#     Letter: o, Color: (168, 210, 240), Style: Regular
#
#
# Word: m
#   Position: x1=1234, y1=117, x2=1265, y2=139
#     Letter: m, Color: (167, 209, 241), Style: Regular
#
#
# Word: e
#   Position: x1=1270, y1=117, x2=1289, y2=139
#     Letter: e, Color: (167, 208, 241), Style: Regular
#
#
# Word: n
#   Position: x1=1294, y1=117, x2=1313, y2=139
#     Letter: n, Color: (166, 207, 242), Style: Regular
#
#
# Word: o
#   Position: x1=1304, y1=108, x2=1328, y2=147
#     Letter: o, Color: (165, 207, 242), Style: Regular
#
#
# Word: n
#   Position: x1=1318, y1=117, x2=1362, y2=139
#     Letter: n, Color: (165, 206, 243), Style: Regular
#
#
# Word: o
#   Position: x1=1376, y1=117, x2=1397, y2=139
#     Letter: o, Color: (163, 204, 244), Style: Regular
#
#
# Word: r
#   Position: x1=1402, y1=117, x2=1415, y2=138
#     Letter: r, Color: (163, 203, 244), Style: Regular
#
#
# Word: c
#   Position: x1=1427, y1=117, x2=1446, y2=139
#     Letter: c, Color: (162, 202, 245), Style: Regular
#
#
# Word: o
#   Position: x1=1448, y1=117, x2=1469, y2=139
#     Letter: o, Color: (161, 201, 245), Style: Regular
#
#
# Word: n
#   Position: x1=1474, y1=117, x2=1493, y2=139
#     Letter: n, Color: (160, 200, 246), Style: Regular
#
#
# Word: d
#   Position: x1=1484, y1=116, x2=1504, y2=147
#     Letter: d, Color: (160, 200, 246), Style: Regular
#
#
# Word: i
#   Position: x1=1498, y1=117, x2=1518, y2=147
#     Letter: i, Color: (160, 200, 246), Style: Regular
#
#
# Word: t
#   Position: x1=1523, y1=117, x2=1530, y2=147
#     Letter: t, Color: (159, 199, 247), Style: Regular
#
#
# Word: i
#   Position: x1=1533, y1=117, x2=1558, y2=147
#     Letter: i, Color: (159, 198, 247), Style: Regular
#
#
# Word: o
#   Position: x1=1562, y1=116, x2=1583, y2=139
#     Letter: o, Color: (158, 197, 247), Style: Regular
#
#
# Word: n
#   Position: x1=1576, y1=116, x2=1596, y2=147
#     Letter: n, Color: (157, 197, 248), Style: Regular
#
#
# Word: .
#   Position: x1=1588, y1=117, x2=1618, y2=139
#     Letter: ., Color: (157, 196, 248), Style: Regular
