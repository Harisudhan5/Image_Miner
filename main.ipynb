# %%
import cv2
import numpy as np
from PIL import Image
import pytesseract

# Load the image
image_path = 'Test Images/3.png'
image = cv2.imread(image_path)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Use Tesseract to extract word boxes and text
boxes_data = pytesseract.image_to_boxes(rgb_image)
extracted_text = pytesseract.image_to_string(rgb_image)

# Convert the image to grayscale for style analysis
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply edge detection
edges = cv2.Canny(gray_image, 50, 150)

# Find contours in the edge-detected image
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Analyze contours to infer style information for each letter
letter_styles = []

for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    
    # Use bounding box information to infer style (e.g., bold or italic)
    aspect_ratio = w / h
    if aspect_ratio > 1.5:
        style = "Bold"
    elif aspect_ratio < 0.5:
        style = "Italic"
    else:
        style = "Regular"

    # Append style for each letter in the contour
    for letter_x in range(x, x + w):
        letter_styles.append(style)

# Iterate through each word box and extract color, style, and position for each word
for box_data in boxes_data.splitlines():
    box = box_data.split()
    x, y, w, h = int(box[1]), int(box[2]), int(box[3]), int(box[4])
    word_image = rgb_image[y:h, x:w]
    average_word_color = np.mean(word_image, axis=(0, 1)).astype(int)
    word = box_data[0]

    # Print each letter, its color, style, and position
    print("Word:", word)
    print("  Position: x1={}, y1={}, x2={}, y2={}".format(x, y, w, h))
    
    # Extract style for each letter in the word
    for i, letter in enumerate(word):
        letter_style = letter_styles[x + i]  # Assuming x is the starting x-coordinate of the word
        print(f"    Letter: {letter}, Color: {tuple(average_word_color)}, Style: {letter_style}")
    print("\n")
# Out:
# Word: H
#   Position: x1=248, y1=898, x2=325, y2=955
#     Letter: H, Color: (255, 182, 21), Style: Regular
#
#
# Word: U
#   Position: x1=335, y1=897, x2=408, y2=955
#     Letter: U, Color: (255, 188, 17), Style: Regular
#
#
# Word: G
#   Position: x1=415, y1=897, x2=494, y2=956
#     Letter: G, Color: (255, 187, 67), Style: Regular
#
#
# Word: G
#   Position: x1=502, y1=897, x2=581, y2=956
#     Letter: G, Color: (255, 194, 94), Style: Regular
#
#
# Word: I
#   Position: x1=592, y1=898, x2=616, y2=955
#     Letter: I, Color: (255, 177, 13), Style: Regular
#
#
# Word: N
#   Position: x1=628, y1=898, x2=713, y2=955
#     Letter: N, Color: (255, 188, 17), Style: Regular
#
#
# Word: G
#   Position: x1=722, y1=897, x2=801, y2=956
#     Letter: G, Color: (255, 184, 38), Style: Regular
#
#
# Word: F
#   Position: x1=832, y1=898, x2=898, y2=955
#     Letter: F, Color: (251, 239, 221), Style: Regular
#
#
# Word: A
#   Position: x1=902, y1=898, x2=996, y2=955
#     Letter: A, Color: (254, 254, 254), Style: Regular
#
#
# Word: C
#   Position: x1=1000, y1=897, x2=1079, y2=956
#     Letter: C, Color: (255, 255, 255), Style: Regular
#
#
# Word: E
#   Position: x1=1089, y1=898, x2=1158, y2=955
#     Letter: E, Color: (255, 255, 255), Style: Regular
#
#
# Word: S
#   Position: x1=1184, y1=897, x2=1253, y2=956
#     Letter: S, Color: (255, 255, 255), Style: Regular
#
#
# Word: P
#   Position: x1=1263, y1=898, x2=1340, y2=955
#     Letter: P, Color: (255, 255, 255), Style: Regular
#
#
# Word: A
#   Position: x1=1344, y1=898, x2=1439, y2=955
#     Letter: A, Color: (255, 255, 255), Style: Regular
#
#
# Word: C
#   Position: x1=1443, y1=897, x2=1522, y2=956
#     Letter: C, Color: (255, 255, 255), Style: Regular
#
#
# Word: E
#   Position: x1=1532, y1=898, x2=1600, y2=955
#     Letter: E, Color: (255, 255, 255), Style: Regular
#
#
# Word: S
#   Position: x1=1606, y1=897, x2=1675, y2=956
#     Letter: S, Color: (255, 255, 255), Style: Regular
#
#
# Word: H
#   Position: x1=1072, y1=587, x2=1111, y2=634
#     Letter: H, Color: (255, 255, 255), Style: Regular
#
#
# Word: u
#   Position: x1=1121, y1=586, x2=1153, y2=622
#     Letter: u, Color: (255, 255, 255), Style: Regular
#
#
# Word: g
#   Position: x1=1159, y1=572, x2=1193, y2=627
#     Letter: g, Color: (222, 222, 222), Style: Regular
#
#
# Word: g
#   Position: x1=1196, y1=572, x2=1230, y2=627
#     Letter: g, Color: (243, 243, 243), Style: Regular
#
#
# Word: i
#   Position: x1=1235, y1=587, x2=1246, y2=637
#     Letter: i, Color: (255, 255, 255), Style: Regular
#
#
# Word: n
#   Position: x1=1255, y1=587, x2=1287, y2=623
#     Letter: n, Color: (255, 255, 255), Style: Regular
#
#
# Word: g
#   Position: x1=1292, y1=572, x2=1327, y2=627
#     Letter: g, Color: (223, 223, 223), Style: Regular
#
#
# Word: F
#   Position: x1=1349, y1=587, x2=1379, y2=634
#     Letter: F, Color: (241, 241, 241), Style: Regular
#
#
# Word: a
#   Position: x1=1383, y1=586, x2=1417, y2=623
#     Letter: a, Color: (221, 221, 221), Style: Regular
#
#
# Word: c
#   Position: x1=1421, y1=586, x2=1453, y2=623
#     Letter: c, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1457, y1=586, x2=1490, y2=623
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: S
#   Position: x1=1510, y1=586, x2=1545, y2=634
#     Letter: S, Color: (243, 243, 243), Style: Regular
#
#
# Word: p
#   Position: x1=1553, y1=573, x2=1587, y2=623
#     Letter: p, Color: (204, 204, 204), Style: Regular
#
#
# Word: a
#   Position: x1=1593, y1=586, x2=1626, y2=623
#     Letter: a, Color: (255, 255, 255), Style: Regular
#
#
# Word: c
#   Position: x1=1630, y1=586, x2=1662, y2=623
#     Letter: c, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1667, y1=586, x2=1699, y2=623
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: s
#   Position: x1=1704, y1=586, x2=1732, y2=623
#     Letter: s, Color: (255, 255, 255), Style: Regular
#
#
# Word: m
#   Position: x1=1044, y1=496, x2=1095, y2=532
#     Letter: m, Color: (255, 255, 255), Style: Regular
#
#
# Word: a
#   Position: x1=1082, y1=495, x2=1120, y2=545
#     Letter: a, Color: (255, 255, 255), Style: Regular
#
#
# Word: k
#   Position: x1=1102, y1=495, x2=1136, y2=532
#     Letter: k, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1142, y1=495, x2=1208, y2=545
#     Letter: e, Color: (217, 217, 217), Style: Regular
#
#
# Word: i
#   Position: x1=1230, y1=496, x2=1241, y2=546
#     Letter: i, Color: (213, 213, 213), Style: Regular
#
#
# Word: t
#   Position: x1=1246, y1=495, x2=1271, y2=539
#     Letter: t, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1291, y1=495, x2=1323, y2=532
#     Letter: e, Color: (199, 199, 199), Style: Regular
#
#
# Word: a
#   Position: x1=1328, y1=495, x2=1362, y2=532
#     Letter: a, Color: (255, 255, 255), Style: Regular
#
#
# Word: s
#   Position: x1=1365, y1=495, x2=1393, y2=532
#     Letter: s, Color: (255, 255, 255), Style: Regular
#
#
# Word: y
#   Position: x1=1396, y1=481, x2=1432, y2=531
#     Letter: y, Color: (219, 219, 219), Style: Regular
#
#
# Word: f
#   Position: x1=1450, y1=496, x2=1475, y2=546
#     Letter: f, Color: (220, 220, 220), Style: Regular
#
#
# Word: o
#   Position: x1=1477, y1=495, x2=1512, y2=532
#     Letter: o, Color: (255, 255, 255), Style: Regular
#
#
# Word: r
#   Position: x1=1520, y1=496, x2=1542, y2=532
#     Letter: r, Color: (255, 255, 255), Style: Regular
#
#
# Word: y
#   Position: x1=1559, y1=481, x2=1595, y2=531
#     Letter: y, Color: (213, 213, 213), Style: Regular
#
#
# Word: o
#   Position: x1=1599, y1=495, x2=1633, y2=532
#     Letter: o, Color: (255, 255, 255), Style: Regular
#
#
# Word: u
#   Position: x1=1641, y1=495, x2=1672, y2=531
#     Letter: u, Color: (255, 255, 255), Style: Regular
#
#
# Word: t
#   Position: x1=1694, y1=495, x2=1719, y2=539
#     Letter: t, Color: (255, 255, 255), Style: Regular
#
#
# Word: o
#   Position: x1=1723, y1=495, x2=1758, y2=532
#     Letter: o, Color: (255, 255, 255), Style: Italic
#
#
# Word: c
#   Position: x1=1045, y1=404, x2=1077, y2=441
#     Letter: c, Color: (255, 255, 255), Style: Regular
#
#
# Word: r
#   Position: x1=1083, y1=405, x2=1105, y2=441
#     Letter: r, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1109, y1=404, x2=1141, y2=441
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: a
#   Position: x1=1147, y1=404, x2=1180, y2=441
#     Letter: a, Color: (255, 255, 255), Style: Regular
#
#
# Word: t
#   Position: x1=1182, y1=404, x2=1207, y2=448
#     Letter: t, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1212, y1=404, x2=1244, y2=441
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: a
#   Position: x1=1265, y1=404, x2=1298, y2=441
#     Letter: a, Color: (255, 255, 255), Style: Regular
#
#
# Word: n
#   Position: x1=1304, y1=405, x2=1336, y2=441
#     Letter: n, Color: (255, 255, 255), Style: Italic
#
#
# Word: d
#   Position: x1=1343, y1=404, x2=1377, y2=454
#     Letter: d, Color: (222, 222, 222), Style: Regular
#
#
# Word: d
#   Position: x1=1401, y1=404, x2=1435, y2=454
#     Letter: d, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1443, y1=404, x2=1476, y2=441
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: p
#   Position: x1=1483, y1=391, x2=1517, y2=441
#     Letter: p, Color: (255, 255, 255), Style: Regular
#
#
# Word: l
#   Position: x1=1525, y1=404, x2=1540, y2=454
#     Letter: l, Color: (216, 216, 216), Style: Regular
#
#
# Word: o
#   Position: x1=1544, y1=404, x2=1579, y2=441
#     Letter: o, Color: (255, 255, 255), Style: Regular
#
#
# Word: y
#   Position: x1=1582, y1=390, x2=1618, y2=440
#     Letter: y, Color: (255, 255, 255), Style: Regular
#
#
# Word: M
#   Position: x1=1641, y1=405, x2=1689, y2=452
#     Letter: M, Color: (255, 255, 255), Style: Regular
#
#
# Word: L
#   Position: x1=1679, y1=405, x2=1717, y2=452
#     Letter: L, Color: (255, 255, 255), Style: Regular
#
#
# Word: -
#   Position: x1=1701, y1=405, x2=1755, y2=452
#     Letter: -, Color: (255, 255, 255), Style: Regular
#
#
# Word: p
#   Position: x1=1112, y1=300, x2=1146, y2=350
#     Letter: p, Color: (255, 255, 255), Style: Regular
#
#
# Word: o
#   Position: x1=1152, y1=313, x2=1187, y2=350
#     Letter: o, Color: (255, 255, 255), Style: Regular
#
#
# Word: w
#   Position: x1=1191, y1=314, x2=1240, y2=349
#     Letter: w, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1222, y1=300, x2=1258, y2=363
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: r
#   Position: x1=1244, y1=313, x2=1277, y2=350
#     Letter: r, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1285, y1=313, x2=1343, y2=350
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: d
#   Position: x1=1348, y1=313, x2=1382, y2=363
#     Letter: d, Color: (255, 255, 255), Style: Regular
#
#
# Word: d
#   Position: x1=1406, y1=313, x2=1440, y2=363
#     Letter: d, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1448, y1=313, x2=1481, y2=350
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: m
#   Position: x1=1488, y1=314, x2=1540, y2=350
#     Letter: m, Color: (255, 255, 255), Style: Regular
#
#
# Word: o
#   Position: x1=1516, y1=313, x2=1552, y2=363
#     Letter: o, Color: (255, 255, 255), Style: Regular
#
#
# Word: s
#   Position: x1=1547, y1=313, x2=1615, y2=350
#     Letter: s, Color: (255, 255, 255), Style: Regular
#
#
# Word: i
#   Position: x1=1637, y1=314, x2=1648, y2=364
#     Letter: i, Color: (255, 255, 255), Style: Regular
#
#
# Word: n
#   Position: x1=1657, y1=314, x2=1688, y2=350
#     Letter: n, Color: (255, 255, 255), Style: Regular
#
#
# Word: m
#   Position: x1=1266, y1=223, x2=1317, y2=259
#     Letter: m, Color: (255, 255, 255), Style: Regular
#
#
# Word: i
#   Position: x1=1326, y1=223, x2=1337, y2=273
#     Letter: i, Color: (255, 255, 255), Style: Regular
#
#
# Word: n
#   Position: x1=1346, y1=223, x2=1377, y2=259
#     Letter: n, Color: (255, 255, 255), Style: Regular
#
#
# Word: u
#   Position: x1=1386, y1=222, x2=1418, y2=258
#     Letter: u, Color: (255, 255, 255), Style: Regular
#
#
# Word: t
#   Position: x1=1403, y1=222, x2=1435, y2=273
#     Letter: t, Color: (255, 255, 255), Style: Regular
#
#
# Word: e
#   Position: x1=1424, y1=222, x2=1449, y2=266
#     Letter: e, Color: (255, 255, 255), Style: Regular
#
#
# Word: s
#   Position: x1=1453, y1=222, x2=1486, y2=259
#     Letter: s, Color: (255, 255, 255), Style: Regular
#
#
# Word: .
#   Position: x1=1490, y1=222, x2=1535, y2=259
#     Letter: ., Color: (255, 255, 255), Style: Regular
#
#
# Word: ~
#   Position: x1=144, y1=110, x2=882, y2=792
#     Letter: ~, Color: (234, 201, 115), Style: Italic

# %%
from PIL import Image
from font_identifier import FontIdentifier
import pytesseract

def ocr_with_font_recognition(image_path):
    # Open the image using PIL
    image = Image.open(image_path)

    # Use Tesseract to do OCR on the image
    text = pytesseract.image_to_string(image)

    # Use FontIdentifier to identify the font
    identifier = FontIdentifier()
    font_info = identifier.identify(text)

    return text, font_info

# Example usage
image_path = 'Test Images//3.png'
result, font_info = ocr_with_font_recognition(image_path)

print("OCR Result:")
print(result)

print("Font Information:")
print(font_info)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from PIL import Image
# ----> 2 from font_identifier import FontIdentifier
#       3 import pytesseract
#       5 def ocr_with_font_recognition(image_path):
#       6     # Open the image using PIL
#
# ModuleNotFoundError: No module named 'font_identifier'
